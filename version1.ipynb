# %%
# !pip install loss-landscape-anim
# pip install -r project_requirements.txt
# %matplotlib notebook

# %%
from loss_landscape_anim import loss_landscape_anim

# %%
# Out:
# '1.1.2'

# %%
loss_landscape_anim(n_epochs = 200)
# Out:
# GPU available: False, used: False
# TPU available: None, using: 0 TPU cores
# Data module not provided, using sample data: spirals dataset
# Model not provided, using default classifier: MLP with 1 hidden layer of 50 neurons
# Model directory /Users/mrnobody/Desktop/WORK/Projects/ML Project/checkpoints does not exist, creating now.
# Training for 200 epochs...
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | accuracy | Accuracy   | 0
# 1 | layers   | Sequential | 303
# ----------------------------------------
# 303       Trainable params
# 0         Non-trainable params
# 303       Total params
# /Users/mrnobody/opt/anaconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Training: |          | 0/? [00:00<?, ?it/s]
# Model saved at /Users/mrnobody/Desktop/WORK/Projects/ML Project/checkpoints/model.pt.
#
# # sampled steps in optimization path: 200
# Dimensionality reduction method specified: pca
# /Users/mrnobody/opt/anaconda3/lib/python3.8/site-packages/loss_landscape_anim/plot.py:213: UserWarning: Less than 300 frames provided, producing 200 frames.
#   warnings.warn(
#   2%|▏         | 218/10000 [00:00<00:04, 2174.02it/s]
# Generating loss values for the contour plot...
# 100%|██████████| 10000/10000 [00:04<00:00, 2353.31it/s]
# Loss values generated.
#
# Loss grid saved at /Users/mrnobody/Desktop/WORK/Projects/ML Project/checkpoints/lossgrid.p.
#
# Total frames to process: 200, result frames per second: 15
# MovieWriter imagemagick unavailable; using Pillow instead.
# Writing sample.gif.
# Processing 200/200 frames...
# Converting to gif, this may take a while...
#
# sample.gif created successfully.

# %%
from loss_landscape_anim import (
    loss_landscape_anim, MNISTDataModule, LeNet
)
bs = 16
lr = 1e-3
datamodule = MNISTDataModule(batch_size=bs, n_examples=3000)
model = LeNet(learning_rate=lr)

optim_path, loss_steps, accu_steps = loss_landscape_anim(
    n_epochs=10,
    model=model,
    datamodule=datamodule,
    optimizer="adam",
    giffps=20,
    seed=180102,
    load_model=False,
    output_to_file=True,
    return_data=True,  # Optional return values if you need them
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/train-images-idx3-ubyte.gz
# |          | 0/? [00:00<?, ?it/s]
# Extracting /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/train-images-idx3-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/train-labels-idx1-ubyte.gz
# |          | 0/? [00:00<?, ?it/s]
# Extracting /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/train-labels-idx1-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/t10k-images-idx3-ubyte.gz
# |          | 0/? [00:00<?, ?it/s]
# Extracting /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/t10k-images-idx3-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/t10k-labels-idx1-ubyte.gz
# |          | 0/? [00:00<?, ?it/s]
# Extracting /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw/t10k-labels-idx1-ubyte.gz to /Users/mrnobody/Desktop/WORK/Projects/ML Project/MNIST/raw
# Processing...
# /Users/mrnobody/opt/anaconda3/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!
# GPU available: False, used: False
# TPU available: None, using: 0 TPU cores
#
#   | Name     | Type      | Params
# ---------------------------------------
# 0 | accuracy | Accuracy  | 0
# 1 | relu     | ReLU      | 0
# 2 | pool     | AvgPool2d | 0
# 3 | conv1    | Conv2d    | 156
# 4 | conv2    | Conv2d    | 2.4 K
# 5 | conv3    | Conv2d    | 48.1 K
# 6 | fc1      | Linear    | 10.2 K
# 7 | fc2      | Linear    | 850
# ---------------------------------------
# 61.7 K    Trainable params
# 0         Non-trainable params
# 61.7 K    Total params
# Training for 10 epochs...
# /Users/mrnobody/opt/anaconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Training: |          | 0/? [00:00<?, ?it/s]
# Model saved at /Users/mrnobody/Desktop/WORK/Projects/ML Project/checkpoints/model.pt.
#
# # sampled steps in optimization path: 300
# Dimensionality reduction method specified: pca
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating loss values for the contour plot...
#   0%|          | 1/10000 [00:00<1:08:07,  2.45it/s]
#
#
#
#   0%|          | 2/10000 [00:00<54:03,  3.08it/s]
#
#
#
#   0%|          | 3/10000 [00:00<47:07,  3.54it/s]
#
#
#
#   0%|          | 4/10000 [00:01<39:22,  4.23it/s]
#
#
#
#   0%|          | 5/10000 [00:01<34:59,  4.76it/s]
#
#
#
#   0%|          | 6/10000 [00:01<32:58,  5.05it/s]
#
#
#
#   0%|          | 7/10000 [00:01<31:28,  5.29it/s]
#
#
#
#   0%|          | 8/10000 [00:01<30:02,  5.54it/s]
#
#
#
#   0%|          | 9/10000 [00:01<28:40,  5.81it/s]
#
#
#
#   0%|          | 10/10000 [00:02<27:41,  6.01it/s]
#
#
#
#   0%|          | 11/10000 [00:02<26:54,  6.19it/s]
#
#
#
#   0%|          | 12/10000 [00:02<26:23,  6.31it/s]
#
#
#
#   0%|          | 13/10000 [00:02<25:53,  6.43it/s]
#
#
#
#   0%|          | 14/10000 [00:02<25:48,  6.45it/s]
#
#
#
#   0%|          | 15/10000 [00:02<25:46,  6.46it/s]
#
#
#
#   0%|          | 16/10000 [00:02<25:48,  6.45it/s]
#
#
#
#   0%|          | 17/10000 [00:03<26:02,  6.39it/s]
#
#
#
#   0%|          | 18/10000 [00:03<25:56,  6.41it/s]
#
#
#
#   0%|          | 19/10000 [00:03<27:04,  6.14it/s]
#
#
#
#   0%|          | 20/10000 [00:03<27:46,  5.99it/s]
#
#
#
#   0%|          | 21/10000 [00:03<28:42,  5.79it/s]
#
#
#
#   0%|          | 22/10000 [00:04<29:14,  5.69it/s]
#
#
#
#   0%|          | 23/10000 [00:04<28:53,  5.76it/s]
#
#
#
#   0%|          | 24/10000 [00:04<28:40,  5.80it/s]
#
#
#
#   0%|          | 25/10000 [00:04<28:47,  5.77it/s]
#
#
#
#   0%|          | 26/10000 [00:04<28:23,  5.85it/s]
#
#
#
#   0%|          | 27/10000 [00:04<27:50,  5.97it/s]
#
#
#
#   0%|          | 28/10000 [00:05<27:40,  6.00it/s]
#
#
#
#   0%|          | 29/10000 [00:05<27:54,  5.95it/s]
#
#
#
#   0%|          | 30/10000 [00:05<27:49,  5.97it/s]
#
#
#
#   0%|          | 31/10000 [00:05<27:44,  5.99it/s]
#
#
#
#   0%|          | 32/10000 [00:05<27:30,  6.04it/s]
#
#
#
#   0%|          | 33/10000 [00:05<27:43,  5.99it/s]
#
#
#
#   0%|          | 34/10000 [00:06<27:47,  5.98it/s]
#
#
#
#   0%|          | 35/10000 [00:06<27:35,  6.02it/s]
#
#
#
#   0%|          | 36/10000 [00:06<27:28,  6.05it/s]
#
#
#
#   0%|          | 37/10000 [00:06<27:24,  6.06it/s]
#
#
#
#   0%|          | 38/10000 [00:06<27:17,  6.08it/s]
#
#
#
#   0%|          | 39/10000 [00:06<27:20,  6.07it/s]
#
#
#
#   0%|          | 40/10000 [00:06<27:05,  6.13it/s]
#
#
#
#   0%|          | 41/10000 [00:07<26:41,  6.22it/s]
#
#
#
#   0%|          | 42/10000 [00:07<26:18,  6.31it/s]
#
#
#
#   0%|          | 43/10000 [00:07<26:01,  6.38it/s]
#
#
#
#   0%|          | 44/10000 [00:07<25:33,  6.49it/s]
#
#
#
#   0%|          | 45/10000 [00:07<25:16,  6.57it/s]
#
#
#
#   0%|          | 46/10000 [00:07<25:06,  6.61it/s]
#
#
#
#   0%|          | 47/10000 [00:08<24:50,  6.68it/s]
#
#
#
#   0%|          | 48/10000 [00:08<24:41,  6.72it/s]
#
#
#
#   0%|          | 49/10000 [00:08<24:49,  6.68it/s]
#
#
#
#   0%|          | 50/10000 [00:08<24:48,  6.68it/s]
#
#
#
#   1%|          | 51/10000 [00:08<25:01,  6.63it/s]
#
#
#
#   1%|          | 52/10000 [00:08<24:50,  6.67it/s]
#
#
#
#   1%|          | 53/10000 [00:08<24:47,  6.69it/s]
#
#
#
#   1%|          | 54/10000 [00:09<24:53,  6.66it/s]
#
#
#
#   1%|          | 55/10000 [00:09<24:55,  6.65it/s]
#
#
#
#   1%|          | 56/10000 [00:09<24:34,  6.74it/s]
#
#
#
#   1%|          | 57/10000 [00:09<24:36,  6.73it/s]
#
#
#
#   1%|          | 58/10000 [00:09<24:41,  6.71it/s]
#
#
#
#   1%|          | 59/10000 [00:09<24:45,  6.69it/s]
#
#
#
#   1%|          | 60/10000 [00:09<24:46,  6.69it/s]
#
#
#
#   1%|          | 61/10000 [00:10<24:49,  6.67it/s]
#
#
#
#   1%|          | 62/10000 [00:10<24:49,  6.67it/s]
#
#
#
#   1%|          | 63/10000 [00:10<24:47,  6.68it/s]
#
#
#
#   1%|          | 64/10000 [00:10<24:51,  6.66it/s]
#
#
#
#   1%|          | 65/10000 [00:10<24:43,  6.70it/s]
#
#
#
#   1%|          | 66/10000 [00:10<24:34,  6.74it/s]
#
#
#
#   1%|          | 67/10000 [00:11<24:36,  6.73it/s]
#
#
#
#   1%|          | 68/10000 [00:11<24:28,  6.76it/s]
#
#
#
#   1%|          | 69/10000 [00:11<24:30,  6.75it/s]
#
#
#
#   1%|          | 70/10000 [00:11<24:35,  6.73it/s]
#
#
#
#   1%|          | 71/10000 [00:11<24:34,  6.73it/s]
#
#
#
#   1%|          | 72/10000 [00:11<24:29,  6.76it/s]
#
#
#
#   1%|          | 73/10000 [00:11<25:59,  6.37it/s]
#
#
#
#   1%|          | 74/10000 [00:12<25:31,  6.48it/s]
#
#
#
#   1%|          | 75/10000 [00:12<25:12,  6.56it/s]
#
#
#
#   1%|          | 76/10000 [00:12<25:03,  6.60it/s]
#
#
#
#   1%|          | 77/10000 [00:12<25:00,  6.61it/s]
#
#
#
#   1%|          | 78/10000 [00:12<24:45,  6.68it/s]
#
#
#
#   1%|          | 79/10000 [00:12<24:49,  6.66it/s]
#
#
#
#   1%|          | 80/10000 [00:12<24:44,  6.68it/s]
#
#
#
#   1%|          | 81/10000 [00:13<24:43,  6.69it/s]
#
#
#
#   1%|          | 82/10000 [00:13<24:33,  6.73it/s]
#
#
#
#   1%|          | 83/10000 [00:13<27:59,  5.90it/s]
#
#
#
#   1%|          | 84/10000 [00:13<27:01,  6.12it/s]
#
#
#
#   1%|          | 85/10000 [00:13<26:15,  6.30it/s]
#
#
#
#   1%|          | 86/10000 [00:13<25:32,  6.47it/s]
#
#
#
#   1%|          | 87/10000 [00:14<25:12,  6.56it/s]
#
#
#
#   1%|          | 88/10000 [00:14<25:05,  6.59it/s]
#
#
#
#   1%|          | 89/10000 [00:14<24:56,  6.62it/s]
#
#
#
#   1%|          | 90/10000 [00:14<24:44,  6.68it/s]
#
#
#
#   1%|          | 91/10000 [00:14<24:40,  6.69it/s]
#
#
#
#   1%|          | 92/10000 [00:14<24:31,  6.73it/s]
#
#
#
#   1%|          | 93/10000 [00:14<24:33,  6.72it/s]
#
#
#
#   1%|          | 94/10000 [00:15<24:32,  6.73it/s]
#
#
#
#   1%|          | 95/10000 [00:15<24:31,  6.73it/s]
#
#
#
#   1%|          | 96/10000 [00:15<24:17,  6.79it/s]
#
#
#
#   1%|          | 97/10000 [00:15<24:10,  6.83it/s]
#
#
#
#   1%|          | 98/10000 [00:15<24:11,  6.82it/s]
#
#
#
#   1%|          | 99/10000 [00:15<24:20,  6.78it/s]
#
#
#
#   1%|          | 100/10000 [00:16<24:24,  6.76it/s]
#
#
#
#   1%|          | 101/10000 [00:16<24:21,  6.77it/s]
#
#
#
#   1%|          | 102/10000 [00:16<24:21,  6.77it/s]
#
#
#
#   1%|          | 103/10000 [00:16<24:22,  6.77it/s]
#
#
#
#   1%|          | 104/10000 [00:16<24:13,  6.81it/s]
#
#
#
#   1%|          | 105/10000 [00:16<24:15,  6.80it/s]
#
#
#
#   1%|          | 106/10000 [00:16<24:11,  6.82it/s]
#
#
#
#   1%|          | 107/10000 [00:17<24:16,  6.79it/s]
#
#
#
#   1%|          | 108/10000 [00:17<24:33,  6.71it/s]
#
#
#
#   1%|          | 109/10000 [00:17<25:03,  6.58it/s]
#
#
#
#   1%|          | 110/10000 [00:17<25:08,  6.56it/s]
#
#
#
#   1%|          | 111/10000 [00:17<25:58,  6.35it/s]
#
#
#
#   1%|          | 112/10000 [00:17<25:41,  6.41it/s]
#
#
#
#   1%|          | 113/10000 [00:17<25:33,  6.45it/s]
#
#
#
#   1%|          | 114/10000 [00:18<25:15,  6.52it/s]
#
#
#
#   1%|          | 115/10000 [00:18<25:02,  6.58it/s]
#
#
#
#   1%|          | 116/10000 [00:18<25:00,  6.59it/s]
#
#
#
#   1%|          | 117/10000 [00:18<28:55,  5.69it/s]
#
#
#
#   1%|          | 118/10000 [00:18<28:10,  5.85it/s]
#
#
#
#   1%|          | 119/10000 [00:18<27:34,  5.97it/s]
#
#
#
#   1%|          | 120/10000 [00:19<27:02,  6.09it/s]
#
#
#
#   1%|          | 121/10000 [00:19<26:47,  6.15it/s]
#
#
#
#   1%|          | 122/10000 [00:19<25:55,  6.35it/s]
#
#
#
#   1%|          | 123/10000 [00:19<25:35,  6.43it/s]
#
#
#
#   1%|          | 124/10000 [00:19<25:15,  6.52it/s]
#
#
#
#   1%|▏         | 125/10000 [00:19<25:01,  6.58it/s]
#
#
#
#   1%|▏         | 126/10000 [00:20<24:53,  6.61it/s]
#
#
#
#   1%|▏         | 127/10000 [00:20<24:45,  6.65it/s]
#
#
#
#   1%|▏         | 128/10000 [00:20<24:30,  6.71it/s]
#
#
#
#   1%|▏         | 129/10000 [00:20<24:32,  6.70it/s]
#
#
#
#   1%|▏         | 130/10000 [00:20<24:44,  6.65it/s]
#
#
#
#   1%|▏         | 131/10000 [00:20<24:52,  6.61it/s]
#
#
#
#   1%|▏         | 132/10000 [00:21<31:30,  5.22it/s]
#
#
#
#   1%|▏         | 133/10000 [00:21<30:16,  5.43it/s]
#
#
#
#   1%|▏         | 134/10000 [00:21<28:32,  5.76it/s]
#
#
#
#   1%|▏         | 135/10000 [00:21<27:29,  5.98it/s]
#
#
#
#   1%|▏         | 136/10000 [00:21<26:46,  6.14it/s]
#
#
#
#   1%|▏         | 137/10000 [00:21<26:18,  6.25it/s]
#
#
#
#   1%|▏         | 138/10000 [00:22<25:38,  6.41it/s]
#
#
#
#   1%|▏         | 139/10000 [00:22<25:14,  6.51it/s]
#
#
#
#   1%|▏         | 140/10000 [00:22<25:05,  6.55it/s]
#
#
#
#   1%|▏         | 141/10000 [00:22<25:08,  6.54it/s]
#
#
#
#   1%|▏         | 142/10000 [00:22<24:59,  6.58it/s]
#
#
#
#   1%|▏         | 143/10000 [00:22<24:57,  6.58it/s]
#
#
#
#   1%|▏         | 144/10000 [00:22<24:45,  6.63it/s]
#
#
#
#   1%|▏         | 145/10000 [00:23<24:44,  6.64it/s]
#
#
#
#   1%|▏         | 146/10000 [00:23<24:31,  6.70it/s]
#
#
#
#   1%|▏         | 147/10000 [00:23<24:32,  6.69it/s]
#
#
#
#   1%|▏         | 148/10000 [00:23<24:33,  6.68it/s]
#
#
#
#   1%|▏         | 149/10000 [00:23<25:50,  6.35it/s]
#
#
#
#   2%|▏         | 150/10000 [00:24<38:37,  4.25it/s]
#
#
#
#   2%|▏         | 151/10000 [00:24<36:17,  4.52it/s]
#
#
#
#   2%|▏         | 152/10000 [00:24<32:43,  5.01it/s]
#
#
#
#   2%|▏         | 153/10000 [00:24<30:16,  5.42it/s]
#
#
#
#   2%|▏         | 154/10000 [00:24<28:26,  5.77it/s]
#
#
#
#   2%|▏         | 155/10000 [00:24<27:10,  6.04it/s]
#
#
#
#   2%|▏         | 156/10000 [00:25<26:16,  6.24it/s]
#
#
#
#   2%|▏         | 157/10000 [00:25<25:40,  6.39it/s]
#
#
#
#   2%|▏         | 158/10000 [00:25<25:13,  6.50it/s]
#
#
#
#   2%|▏         | 159/10000 [00:25<24:58,  6.57it/s]
#
#
#
#   2%|▏         | 160/10000 [00:25<24:53,  6.59it/s]
#
#
#
#   2%|▏         | 161/10000 [00:25<24:55,  6.58it/s]
#
#
#
#   2%|▏         | 162/10000 [00:25<24:48,  6.61it/s]
#
#
#
#   2%|▏         | 163/10000 [00:26<24:41,  6.64it/s]
#
#
#
#   2%|▏         | 164/10000 [00:26<24:37,  6.66it/s]
#
#
#
#   2%|▏         | 165/10000 [00:26<24:32,  6.68it/s]
#
#
#
#   2%|▏         | 166/10000 [00:26<24:30,  6.69it/s]
#
#
#
#   2%|▏         | 167/10000 [00:26<24:46,  6.62it/s]
#
#
#
#   2%|▏         | 168/10000 [00:26<25:00,  6.55it/s]
#
#
#
#   2%|▏         | 169/10000 [00:26<25:20,  6.46it/s]
#
#
#
#   2%|▏         | 170/10000 [00:27<25:14,  6.49it/s]
#
#
#
#   2%|▏         | 171/10000 [00:27<25:32,  6.41it/s]
#
#
#
#   2%|▏         | 172/10000 [00:27<25:36,  6.40it/s]
#
#
#
#   2%|▏         | 173/10000 [00:27<25:14,  6.49it/s]
#
#
#
#   2%|▏         | 174/10000 [00:27<25:06,  6.52it/s]
#
#
#
#   2%|▏         | 175/10000 [00:27<25:06,  6.52it/s]
#
#
#
#   2%|▏         | 176/10000 [00:28<25:52,  6.33it/s]
#
#
#
#   2%|▏         | 177/10000 [00:28<27:26,  5.97it/s]
#
#
#
#   2%|▏         | 178/10000 [00:28<26:35,  6.15it/s]
#
#
#
#   2%|▏         | 179/10000 [00:28<25:51,  6.33it/s]
#
#
#
#   2%|▏         | 180/10000 [00:28<25:17,  6.47it/s]
#
#
#
#   2%|▏         | 181/10000 [00:28<25:00,  6.54it/s]
#
#
#
#   2%|▏         | 182/10000 [00:29<25:03,  6.53it/s]
#
#
#
#   2%|▏         | 183/10000 [00:29<25:03,  6.53it/s]
#
#
#
#   2%|▏         | 184/10000 [00:29<24:52,  6.58it/s]
#
#
#
#   2%|▏         | 185/10000 [00:29<24:40,  6.63it/s]
#
#
#
#   2%|▏         | 186/10000 [00:29<24:33,  6.66it/s]
#
#
#
#   2%|▏         | 187/10000 [00:29<24:38,  6.64it/s]
#
#
#
#   2%|▏         | 188/10000 [00:29<24:53,  6.57it/s]
#
#
#
#   2%|▏         | 189/10000 [00:30<24:52,  6.57it/s]
#
#
#
#   2%|▏         | 190/10000 [00:30<24:50,  6.58it/s]
#
#
#
#   2%|▏         | 191/10000 [00:30<24:57,  6.55it/s]
#
#
#
#   2%|▏         | 192/10000 [00:30<24:52,  6.57it/s]
#
#
#
#   2%|▏         | 193/10000 [00:30<26:01,  6.28it/s]
#
#
#
#   2%|▏         | 194/10000 [00:30<25:49,  6.33it/s]
#
#
#
#   2%|▏         | 195/10000 [00:31<25:43,  6.35it/s]
#
#
#
#   2%|▏         | 196/10000 [00:31<25:54,  6.31it/s]
#
#
#
#   2%|▏         | 197/10000 [00:31<25:36,  6.38it/s]
#
#
#
#   2%|▏         | 198/10000 [00:31<25:57,  6.29it/s]
#
#
#
#   2%|▏         | 199/10000 [00:31<26:24,  6.18it/s]
#
#
#
#   2%|▏         | 200/10000 [00:31<26:08,  6.25it/s]
#
#
#
#   2%|▏         | 201/10000 [00:31<26:01,  6.28it/s]
#
#
#
#   2%|▏         | 202/10000 [00:32<25:30,  6.40it/s]
#
#
#
#   2%|▏         | 203/10000 [00:32<25:31,  6.40it/s]
#
#
#
#   2%|▏         | 204/10000 [00:32<25:19,  6.45it/s]
#
#
#
#   2%|▏         | 205/10000 [00:32<25:07,  6.50it/s]
#
#
#
#   2%|▏         | 206/10000 [00:32<25:07,  6.49it/s]
#
#
#
#   2%|▏         | 207/10000 [00:32<25:05,  6.51it/s]
#
#
#
#   2%|▏         | 208/10000 [00:33<25:16,  6.46it/s]
#
#
#
#   2%|▏         | 209/10000 [00:33<25:06,  6.50it/s]
#
#
#
#   2%|▏         | 210/10000 [00:33<25:21,  6.44it/s]
#
#
#
#   2%|▏         | 211/10000 [00:33<25:24,  6.42it/s]
#
#
#
#   2%|▏         | 212/10000 [00:33<25:22,  6.43it/s]
#
#
#
#   2%|▏         | 213/10000 [00:33<25:10,  6.48it/s]
#
#
#
#   2%|▏         | 214/10000 [00:33<25:09,  6.48it/s]
#
#
#
#   2%|▏         | 215/10000 [00:34<25:12,  6.47it/s]
#
#
#
#   2%|▏         | 216/10000 [00:34<25:10,  6.48it/s]
#
#
#
#   2%|▏         | 217/10000 [00:34<25:31,  6.39it/s]
#
#
#
#   2%|▏         | 218/10000 [00:34<25:22,  6.42it/s]
#
#
#
#   2%|▏         | 219/10000 [00:34<25:22,  6.42it/s]
#
#
#
#   2%|▏         | 220/10000 [00:34<25:19,  6.44it/s]
#
#
#
#   2%|▏         | 221/10000 [00:35<25:04,  6.50it/s]
#
#
#
#   2%|▏         | 222/10000 [00:35<25:08,  6.48it/s]
#
#
#
#   2%|▏         | 223/10000 [00:35<24:59,  6.52it/s]
#
#
#
#   2%|▏         | 224/10000 [00:35<25:06,  6.49it/s]
#
#
#
#   2%|▏         | 225/10000 [00:35<25:03,  6.50it/s]
#
#
#
#   2%|▏         | 226/10000 [00:35<24:58,  6.52it/s]
#
#
#
#   2%|▏         | 227/10000 [00:35<24:55,  6.53it/s]
#
#
#
#   2%|▏         | 228/10000 [00:36<24:56,  6.53it/s]
#
#
#
#   2%|▏         | 229/10000 [00:36<24:58,  6.52it/s]
#
#
#
#   2%|▏         | 230/10000 [00:36<24:50,  6.55it/s]
#
#
#
#   2%|▏         | 231/10000 [00:36<24:47,  6.57it/s]
#
#
#
#   2%|▏         | 232/10000 [00:36<24:34,  6.62it/s]
#
#
#
#   2%|▏         | 233/10000 [00:36<24:45,  6.58it/s]
#
#
#
#   2%|▏         | 234/10000 [00:37<24:38,  6.61it/s]
#
#
#
#   2%|▏         | 235/10000 [00:37<24:37,  6.61it/s]
#
#
#
#   2%|▏         | 236/10000 [00:37<24:41,  6.59it/s]
#
#
#
#   2%|▏         | 237/10000 [00:37<24:36,  6.61it/s]
#
#
#
#   2%|▏         | 238/10000 [00:37<24:37,  6.61it/s]
#
#
#
#   2%|▏         | 239/10000 [00:37<24:44,  6.58it/s]
#
#
#
#   2%|▏         | 240/10000 [00:37<24:56,  6.52it/s]
#
#
#
#   2%|▏         | 241/10000 [00:38<24:59,  6.51it/s]
#
#
#
#   2%|▏         | 242/10000 [00:38<24:51,  6.54it/s]
#
#
#
#   2%|▏         | 243/10000 [00:38<24:58,  6.51it/s]
#
#
#
#   2%|▏         | 244/10000 [00:38<25:11,  6.46it/s]
#
#
#
#   2%|▏         | 245/10000 [00:38<25:08,  6.47it/s]
#   2%|▏         | 246/10000 [00:38<24:57,  6.51it/s]
#
#
#
#   2%|▏         | 247/10000 [00:39<24:54,  6.53it/s]
#
#
#
#   2%|▏         | 248/10000 [00:39<24:53,  6.53it/s]
#
#
#
#   2%|▏         | 249/10000 [00:39<24:42,  6.58it/s]
#
#
#
#   2%|▎         | 250/10000 [00:39<24:45,  6.56it/s]
#
#
#
#   3%|▎         | 251/10000 [00:39<24:49,  6.55it/s]
#
#
#
#   3%|▎         | 252/10000 [00:39<24:44,  6.57it/s]
#
#
#
#   3%|▎         | 253/10000 [00:39<24:34,  6.61it/s]
#
#
#
#   3%|▎         | 254/10000 [00:40<24:34,  6.61it/s]
#
#
#
#   3%|▎         | 255/10000 [00:40<24:38,  6.59it/s]
#
#
#
#   3%|▎         | 256/10000 [00:40<24:28,  6.63it/s]
#
#
#
#   3%|▎         | 257/10000 [00:40<24:38,  6.59it/s]
#
#
#
#   3%|▎         | 258/10000 [00:40<24:40,  6.58it/s]
#
#
#
#   3%|▎         | 259/10000 [00:40<24:36,  6.60it/s]
#
#
#
#   3%|▎         | 260/10000 [00:41<24:30,  6.62it/s]
#
#
#
#   3%|▎         | 261/10000 [00:41<24:40,  6.58it/s]
#
#
#
#   3%|▎         | 262/10000 [00:41<24:27,  6.64it/s]
#
#
#
#   3%|▎         | 263/10000 [00:41<24:34,  6.60it/s]
#
#
#
#   3%|▎         | 264/10000 [00:41<24:42,  6.57it/s]
#
#
#
#   3%|▎         | 265/10000 [00:41<24:36,  6.59it/s]
#
#
#
#   3%|▎         | 266/10000 [00:41<24:33,  6.61it/s]
#
#
#
#   3%|▎         | 267/10000 [00:42<24:34,  6.60it/s]
#
#
#
#   3%|▎         | 268/10000 [00:42<24:38,  6.58it/s]
#
#
#
#   3%|▎         | 269/10000 [00:42<24:32,  6.61it/s]
#
#
#
#   3%|▎         | 270/10000 [00:42<24:33,  6.60it/s]
#
#
#
#   3%|▎         | 271/10000 [00:42<24:33,  6.60it/s]
#
#
#
#   3%|▎         | 272/10000 [00:42<24:35,  6.59it/s]
#
#
#
#   3%|▎         | 273/10000 [00:42<24:32,  6.60it/s]
#
#
#
#   3%|▎         | 274/10000 [00:43<24:25,  6.64it/s]
#
#
#
#   3%|▎         | 275/10000 [00:43<24:28,  6.62it/s]
#
#
#
#   3%|▎         | 276/10000 [00:43<24:30,  6.61it/s]
#
#
#
#   3%|▎         | 277/10000 [00:43<24:32,  6.60it/s]
#
#
#
#   3%|▎         | 278/10000 [00:43<24:31,  6.61it/s]
#
#
#
#   3%|▎         | 279/10000 [00:43<24:36,  6.58it/s]
#
#
#
#   3%|▎         | 280/10000 [00:44<24:30,  6.61it/s]
#
#
#
#   3%|▎         | 281/10000 [00:44<25:07,  6.45it/s]
#
#
#
#   3%|▎         | 282/10000 [00:44<24:51,  6.52it/s]
#
#
#
#   3%|▎         | 283/10000 [00:44<24:41,  6.56it/s]
#
#
#
#   3%|▎         | 284/10000 [00:44<24:37,  6.58it/s]
#
#
#
#   3%|▎         | 285/10000 [00:44<24:32,  6.60it/s]
#
#
#
#   3%|▎         | 286/10000 [00:44<24:27,  6.62it/s]
#
#
#
#   3%|▎         | 287/10000 [00:45<24:33,  6.59it/s]
#
#
#
#   3%|▎         | 288/10000 [00:45<24:24,  6.63it/s]
#
#
#
#   3%|▎         | 289/10000 [00:45<24:26,  6.62it/s]
#
#
#
#   3%|▎         | 290/10000 [00:45<24:27,  6.62it/s]
#
#
#
#   3%|▎         | 291/10000 [00:45<24:22,  6.64it/s]
#
#
#
#   3%|▎         | 292/10000 [00:45<24:18,  6.65it/s]
#
#
#
#   3%|▎         | 293/10000 [00:46<24:26,  6.62it/s]
#
#
#
#   3%|▎         | 294/10000 [00:46<24:17,  6.66it/s]
#
#
#
#   3%|▎         | 295/10000 [00:46<24:15,  6.67it/s]
#
#
#
#   3%|▎         | 296/10000 [00:46<24:22,  6.64it/s]
#
#
#
#   3%|▎         | 297/10000 [00:46<24:21,  6.64it/s]
#
#
#
#   3%|▎         | 298/10000 [00:46<24:18,  6.65it/s]
#
#
#
#   3%|▎         | 299/10000 [00:46<24:24,  6.63it/s]
#
#
#
#   3%|▎         | 300/10000 [00:47<24:17,  6.65it/s]
#
#
#
#   3%|▎         | 301/10000 [00:47<24:12,  6.68it/s]
#
#
#
#   3%|▎         | 302/10000 [00:47<24:16,  6.66it/s]
#
#
#
#   3%|▎         | 303/10000 [00:47<24:16,  6.66it/s]
#
#
#
#   3%|▎         | 304/10000 [00:47<24:13,  6.67it/s]
#
#
#
#   3%|▎         | 305/10000 [00:47<24:27,  6.61it/s]
#
#
#
#   3%|▎         | 306/10000 [00:47<24:26,  6.61it/s]
#
#
#
#   3%|▎         | 307/10000 [00:48<24:27,  6.61it/s]
#
#
#
#   3%|▎         | 308/10000 [00:48<24:35,  6.57it/s]
#
#
#
#   3%|▎         | 309/10000 [00:48<24:46,  6.52it/s]
#
#
#
#   3%|▎         | 310/10000 [00:48<24:33,  6.58it/s]
#
#
#
#   3%|▎         | 311/10000 [00:48<24:37,  6.56it/s]
#
#
#
#   3%|▎         | 312/10000 [00:48<24:28,  6.60it/s]
#
#
#
#   3%|▎         | 313/10000 [00:49<24:24,  6.62it/s]
#
#
#
#   3%|▎         | 314/10000 [00:49<24:22,  6.62it/s]
#
#
#
#   3%|▎         | 315/10000 [00:49<24:21,  6.63it/s]
#
#
#
#   3%|▎         | 316/10000 [00:49<24:24,  6.61it/s]
#
#
#
#   3%|▎         | 317/10000 [00:49<24:34,  6.57it/s]
#
#
#
#   3%|▎         | 318/10000 [00:49<24:31,  6.58it/s]
#
#
#
#   3%|▎         | 319/10000 [00:49<24:29,  6.59it/s]
#
#
#
#   3%|▎         | 320/10000 [00:50<24:26,  6.60it/s]
#
#
#
#   3%|▎         | 321/10000 [00:50<24:21,  6.62it/s]
#
#
#
#   3%|▎         | 322/10000 [00:50<24:18,  6.63it/s]
#
#
#
#   3%|▎         | 323/10000 [00:50<24:27,  6.59it/s]
#
#
#
#   3%|▎         | 324/10000 [00:50<24:29,  6.59it/s]
#
#
#
#   3%|▎         | 325/10000 [00:50<24:23,  6.61it/s]
#
#
#
#   3%|▎         | 326/10000 [00:50<24:33,  6.56it/s]
#
#
#
#   3%|▎         | 327/10000 [00:51<24:30,  6.58it/s]
#
#
#
#   3%|▎         | 328/10000 [00:51<24:24,  6.60it/s]
#
#
#
#   3%|▎         | 329/10000 [00:51<24:22,  6.61it/s]
#
#
#
#   3%|▎         | 330/10000 [00:51<24:13,  6.65it/s]
#
#
#
#   3%|▎         | 331/10000 [00:51<24:23,  6.61it/s]
#
#
#
#   3%|▎         | 332/10000 [00:51<24:24,  6.60it/s]
#
#
#
#   3%|▎         | 333/10000 [00:52<24:26,  6.59it/s]
#
#
#
#   3%|▎         | 334/10000 [00:52<24:22,  6.61it/s]
#
#
#
#   3%|▎         | 335/10000 [00:52<24:20,  6.62it/s]
#
#
#
#   3%|▎         | 336/10000 [00:52<24:42,  6.52it/s]
#
#
#
#   3%|▎         | 337/10000 [00:52<26:16,  6.13it/s]
#
#
#
#   3%|▎         | 338/10000 [00:52<25:50,  6.23it/s]
#
#
#
#   3%|▎         | 339/10000 [00:53<25:20,  6.35it/s]
#
#
#
#   3%|▎         | 340/10000 [00:53<25:06,  6.41it/s]
#
#
#
#   3%|▎         | 341/10000 [00:53<24:45,  6.50it/s]
#
#
#
#   3%|▎         | 342/10000 [00:53<24:33,  6.55it/s]
#
#
#
#   3%|▎         | 343/10000 [00:53<24:29,  6.57it/s]
#
#
#
#   3%|▎         | 344/10000 [00:53<24:35,  6.54it/s]
#
#
#
#   3%|▎         | 345/10000 [00:53<24:28,  6.57it/s]
#
#
#
#   3%|▎         | 346/10000 [00:54<24:22,  6.60it/s]
#
#
#
#   3%|▎         | 347/10000 [00:54<24:20,  6.61it/s]
#
#
#
#   3%|▎         | 348/10000 [00:54<24:29,  6.57it/s]
#
#
#
#   3%|▎         | 349/10000 [00:54<24:36,  6.54it/s]
#
#
#
#   4%|▎         | 350/10000 [00:54<24:27,  6.57it/s]
#
#
#
#   4%|▎         | 351/10000 [00:54<24:21,  6.60it/s]
#
#
#
#   4%|▎         | 352/10000 [00:54<24:16,  6.62it/s]
#
#
#
#   4%|▎         | 353/10000 [00:55<24:12,  6.64it/s]
#
#
#
#   4%|▎         | 354/10000 [00:55<24:07,  6.66it/s]
#
#
#
#   4%|▎         | 355/10000 [00:55<24:07,  6.66it/s]
#
#
#
#   4%|▎         | 356/10000 [00:55<24:09,  6.65it/s]
#
#
#
#   4%|▎         | 357/10000 [00:55<24:22,  6.59it/s]
#
#
#
#   4%|▎         | 358/10000 [00:55<24:25,  6.58it/s]
#
#
#
#   4%|▎         | 359/10000 [00:56<24:15,  6.63it/s]
#
#
#
#   4%|▎         | 360/10000 [00:56<24:09,  6.65it/s]
#
#
#
#   4%|▎         | 361/10000 [00:56<24:06,  6.67it/s]
#
#
#
#   4%|▎         | 362/10000 [00:56<24:06,  6.67it/s]
#
#
#
#   4%|▎         | 363/10000 [00:56<24:14,  6.62it/s]
#
#
#
#   4%|▎         | 364/10000 [00:56<24:14,  6.62it/s]
#
#
#
#   4%|▎         | 365/10000 [00:56<24:14,  6.63it/s]
#
#
#
#   4%|▎         | 366/10000 [00:57<24:08,  6.65it/s]
#
#
#
#   4%|▎         | 367/10000 [00:57<24:08,  6.65it/s]
#
#
#
#   4%|▎         | 368/10000 [00:57<24:03,  6.67it/s]
#
#
#
#   4%|▎         | 369/10000 [00:57<24:03,  6.67it/s]
#
#
#
#   4%|▎         | 370/10000 [00:57<24:00,  6.69it/s]
#
#
#
#   4%|▎         | 371/10000 [00:57<23:58,  6.69it/s]
#
#
#
#   4%|▎         | 372/10000 [00:57<23:53,  6.72it/s]
#
#
#
#   4%|▎         | 373/10000 [00:58<23:50,  6.73it/s]
#
#
#
#   4%|▎         | 374/10000 [00:58<23:45,  6.75it/s]
#
#
#
#   4%|▍         | 375/10000 [00:58<23:42,  6.76it/s]
#
#
#
#   4%|▍         | 376/10000 [00:58<23:42,  6.76it/s]
#
#
#
#   4%|▍         | 377/10000 [00:58<23:48,  6.74it/s]
#
#
#
#   4%|▍         | 378/10000 [00:58<23:46,  6.74it/s]
#
#
#
#   4%|▍         | 379/10000 [00:59<23:44,  6.76it/s]
#
#
#
#   4%|▍         | 380/10000 [00:59<23:43,  6.76it/s]
#
#
#
#   4%|▍         | 381/10000 [00:59<23:49,  6.73it/s]
#
#
#
#   4%|▍         | 382/10000 [00:59<23:49,  6.73it/s]
#
#
#
#   4%|▍         | 383/10000 [00:59<23:53,  6.71it/s]
#
#
#
#   4%|▍         | 384/10000 [00:59<24:35,  6.52it/s]
#
#
#
#   4%|▍         | 385/10000 [00:59<25:06,  6.38it/s]
#
#
#
#   4%|▍         | 386/10000 [01:00<25:00,  6.41it/s]
#
#
#
#   4%|▍         | 387/10000 [01:00<25:05,  6.38it/s]
#
#
#
#   4%|▍         | 388/10000 [01:00<25:21,  6.32it/s]
#
#
#
#   4%|▍         | 389/10000 [01:00<26:00,  6.16it/s]
#
#
#
#   4%|▍         | 390/10000 [01:00<32:17,  4.96it/s]
#
#
#
#   4%|▍         | 391/10000 [01:01<39:58,  4.01it/s]
#
#
#
#   4%|▍         | 392/10000 [01:01<36:24,  4.40it/s]
#
#
#
#   4%|▍         | 393/10000 [01:01<34:35,  4.63it/s]
#
#
#
#   4%|▍         | 394/10000 [01:01<32:44,  4.89it/s]
#
#
#
#   4%|▍         | 395/10000 [01:01<30:28,  5.25it/s]
#
#
#
#   4%|▍         | 396/10000 [01:02<28:35,  5.60it/s]
#
#
#
#   4%|▍         | 397/10000 [01:02<27:18,  5.86it/s]
#
#
#
#   4%|▍         | 398/10000 [01:02<26:13,  6.10it/s]
#
#
#
#   4%|▍         | 399/10000 [01:02<25:45,  6.21it/s]
#
#
#
#   4%|▍         | 400/10000 [01:02<25:05,  6.38it/s]
#
#
#
#   4%|▍         | 401/10000 [01:02<24:53,  6.43it/s]
#
#
#
#   4%|▍         | 402/10000 [01:02<24:35,  6.51it/s]
#
#
#
#   4%|▍         | 403/10000 [01:03<24:20,  6.57it/s]
#
#
#
#   4%|▍         | 404/10000 [01:03<24:12,  6.61it/s]
#
#
#
#   4%|▍         | 405/10000 [01:03<24:02,  6.65it/s]
#
#
#
#   4%|▍         | 406/10000 [01:03<23:56,  6.68it/s]
#
#
#
#   4%|▍         | 407/10000 [01:03<23:58,  6.67it/s]
#
#
#
#   4%|▍         | 408/10000 [01:03<24:11,  6.61it/s]
#
#
#
#   4%|▍         | 409/10000 [01:04<24:28,  6.53it/s]
#
#
#
#   4%|▍         | 410/10000 [01:04<24:43,  6.47it/s]
#
#
#
#   4%|▍         | 411/10000 [01:04<24:58,  6.40it/s]
#
#
#
#   4%|▍         | 412/10000 [01:04<24:53,  6.42it/s]
#
#
#
#   4%|▍         | 413/10000 [01:04<24:39,  6.48it/s]
#
#
#
#   4%|▍         | 414/10000 [01:04<24:25,  6.54it/s]
#
#
#
#   4%|▍         | 415/10000 [01:04<24:08,  6.62it/s]
#
#
#
#   4%|▍         | 416/10000 [01:05<23:56,  6.67it/s]
#
#
#
#   4%|▍         | 417/10000 [01:05<23:42,  6.73it/s]
#
#
#
#   4%|▍         | 418/10000 [01:05<27:06,  5.89it/s]
#
#
#
#   4%|▍         | 419/10000 [01:05<26:09,  6.10it/s]
#
#
#
#   4%|▍         | 420/10000 [01:05<25:32,  6.25it/s]
#
#
#
#   4%|▍         | 421/10000 [01:05<25:11,  6.34it/s]
#
#
#
#   4%|▍         | 422/10000 [01:06<24:50,  6.43it/s]
#
#
#
#   4%|▍         | 423/10000 [01:06<24:40,  6.47it/s]
#
#
#
#   4%|▍         | 424/10000 [01:06<24:34,  6.49it/s]
#
#
#
#   4%|▍         | 425/10000 [01:06<24:26,  6.53it/s]
#
#
#
#   4%|▍         | 426/10000 [01:06<24:07,  6.61it/s]
#
#
#
#   4%|▍         | 427/10000 [01:06<24:00,  6.64it/s]
#
#
#
#   4%|▍         | 428/10000 [01:06<23:42,  6.73it/s]
#
#
#
#   4%|▍         | 429/10000 [01:07<23:38,  6.75it/s]
#
#
#
#   4%|▍         | 430/10000 [01:07<23:45,  6.71it/s]
#
#
#
#   4%|▍         | 431/10000 [01:07<23:44,  6.72it/s]
#
#
#
#   4%|▍         | 432/10000 [01:07<23:43,  6.72it/s]
#
#
#
#   4%|▍         | 433/10000 [01:07<23:48,  6.70it/s]
#
#
#
#   4%|▍         | 434/10000 [01:07<23:46,  6.70it/s]
#
#
#
#   4%|▍         | 435/10000 [01:08<23:46,  6.71it/s]
#
#
#
#   4%|▍         | 436/10000 [01:08<23:54,  6.67it/s]
#
#
#
#   4%|▍         | 437/10000 [01:08<23:49,  6.69it/s]
#
#
#
#   4%|▍         | 438/10000 [01:08<23:40,  6.73it/s]
#
#
#
#   4%|▍         | 439/10000 [01:08<23:42,  6.72it/s]
#
#
#
#   4%|▍         | 440/10000 [01:08<23:32,  6.77it/s]
#
#
#
#   4%|▍         | 441/10000 [01:08<23:34,  6.76it/s]
#
#
#
#   4%|▍         | 442/10000 [01:09<23:22,  6.81it/s]
#
#
#
#   4%|▍         | 443/10000 [01:09<23:26,  6.79it/s]
#
#
#
#   4%|▍         | 444/10000 [01:09<23:28,  6.78it/s]
#
#
#
#   4%|▍         | 445/10000 [01:09<23:30,  6.77it/s]
#
#
#
#   4%|▍         | 446/10000 [01:09<23:23,  6.81it/s]
#
#
#
#   4%|▍         | 447/10000 [01:09<23:25,  6.80it/s]
#
#
#
#   4%|▍         | 448/10000 [01:09<23:17,  6.84it/s]
#
#
#
#   4%|▍         | 449/10000 [01:10<23:10,  6.87it/s]
#
#
#
#   4%|▍         | 450/10000 [01:10<23:04,  6.90it/s]
#
#
#
#   5%|▍         | 451/10000 [01:10<23:13,  6.85it/s]
#
#
#
#   5%|▍         | 452/10000 [01:10<23:10,  6.87it/s]
#
#
#
#   5%|▍         | 453/10000 [01:10<23:08,  6.87it/s]
#
#
#
#   5%|▍         | 454/10000 [01:10<23:05,  6.89it/s]
#
#
#
#   5%|▍         | 455/10000 [01:10<23:06,  6.89it/s]
#
#
#
#   5%|▍         | 456/10000 [01:11<23:05,  6.89it/s]
#
#
#
#   5%|▍         | 457/10000 [01:11<23:07,  6.88it/s]
#
#
#
#   5%|▍         | 458/10000 [01:11<23:08,  6.87it/s]
#
#
#
#   5%|▍         | 459/10000 [01:11<23:16,  6.83it/s]
#
#
#
#   5%|▍         | 460/10000 [01:11<23:11,  6.85it/s]
#
#
#
#   5%|▍         | 461/10000 [01:11<23:16,  6.83it/s]
#
#
#
#   5%|▍         | 462/10000 [01:11<23:24,  6.79it/s]
#
#
#
#   5%|▍         | 463/10000 [01:12<23:44,  6.70it/s]
#
#
#
#   5%|▍         | 464/10000 [01:12<23:52,  6.66it/s]
#
#
#
#   5%|▍         | 465/10000 [01:12<23:40,  6.71it/s]
#
#
#
#   5%|▍         | 466/10000 [01:12<23:28,  6.77it/s]
#
#
#
#   5%|▍         | 467/10000 [01:12<23:30,  6.76it/s]
#
#
#
#   5%|▍         | 468/10000 [01:12<23:41,  6.71it/s]
#
#
#
#   5%|▍         | 469/10000 [01:13<23:41,  6.71it/s]
#
#
#
#   5%|▍         | 470/10000 [01:13<23:37,  6.72it/s]
#
#
#
#   5%|▍         | 471/10000 [01:13<23:31,  6.75it/s]
#
#
#
#   5%|▍         | 472/10000 [01:13<23:30,  6.76it/s]
#
#
#
#   5%|▍         | 473/10000 [01:13<23:25,  6.78it/s]
#
#
#
#   5%|▍         | 474/10000 [01:13<23:33,  6.74it/s]
#
#
#
#   5%|▍         | 475/10000 [01:13<23:32,  6.74it/s]
#
#
#
#   5%|▍         | 476/10000 [01:14<23:19,  6.81it/s]
#
#
#
#   5%|▍         | 477/10000 [01:14<23:27,  6.77it/s]
#
#
#
#   5%|▍         | 478/10000 [01:14<23:32,  6.74it/s]
#
#
#
#   5%|▍         | 479/10000 [01:14<23:36,  6.72it/s]
#
#
#
#   5%|▍         | 480/10000 [01:14<23:24,  6.78it/s]
#
#
#
#   5%|▍         | 481/10000 [01:14<23:24,  6.78it/s]
#
#
#
#   5%|▍         | 482/10000 [01:14<23:34,  6.73it/s]
#
#
#
#   5%|▍         | 483/10000 [01:15<23:45,  6.68it/s]
#
#
#
#   5%|▍         | 484/10000 [01:15<23:40,  6.70it/s]
#
#
#
#   5%|▍         | 485/10000 [01:15<23:45,  6.68it/s]
#
#
#
#   5%|▍         | 486/10000 [01:15<23:41,  6.69it/s]
#
#
#
#   5%|▍         | 487/10000 [01:15<23:43,  6.68it/s]
#
#
#
#   5%|▍         | 488/10000 [01:15<23:32,  6.73it/s]
#
#
#
#   5%|▍         | 489/10000 [01:15<23:31,  6.74it/s]
#   5%|▍         | 490/10000 [01:16<23:26,  6.76it/s]
#
#
#
#   5%|▍         | 491/10000 [01:16<23:27,  6.76it/s]
#
#
#
#   5%|▍         | 492/10000 [01:16<23:13,  6.82it/s]
#
#
#
#   5%|▍         | 493/10000 [01:16<23:23,  6.77it/s]
#
#
#
#   5%|▍         | 494/10000 [01:16<23:25,  6.76it/s]
#
#
#
#   5%|▍         | 495/10000 [01:16<23:27,  6.75it/s]
#
#
#
#   5%|▍         | 496/10000 [01:17<23:42,  6.68it/s]
#
#
#
#   5%|▍         | 497/10000 [01:17<23:44,  6.67it/s]
#
#
#
#   5%|▍         | 498/10000 [01:17<23:44,  6.67it/s]
#
#
#
#   5%|▍         | 499/10000 [01:17<24:02,  6.59it/s]
#
#
#
#   5%|▌         | 500/10000 [01:17<24:06,  6.57it/s]
#
#
#
#   5%|▌         | 501/10000 [01:17<28:19,  5.59it/s]
#
#
#
#   5%|▌         | 502/10000 [01:18<27:10,  5.82it/s]
#
#
#
#   5%|▌         | 503/10000 [01:18<26:26,  5.99it/s]
#
#
#
#   5%|▌         | 504/10000 [01:18<26:02,  6.08it/s]
#
#
#
#   5%|▌         | 505/10000 [01:18<25:40,  6.16it/s]
#
#
#
#   5%|▌         | 506/10000 [01:18<25:15,  6.26it/s]
#
#
#
#   5%|▌         | 507/10000 [01:18<24:59,  6.33it/s]
#
#
#
#   5%|▌         | 508/10000 [01:18<25:10,  6.29it/s]
#
#
#
#   5%|▌         | 509/10000 [01:19<24:43,  6.40it/s]
#
#
#
#   5%|▌         | 510/10000 [01:19<24:20,  6.50it/s]
#
#
#
#   5%|▌         | 511/10000 [01:19<24:01,  6.58it/s]
#
#
#
#   5%|▌         | 512/10000 [01:19<24:03,  6.57it/s]
#
#
#
#   5%|▌         | 513/10000 [01:19<23:53,  6.62it/s]
#
#
#
#   5%|▌         | 514/10000 [01:19<23:42,  6.67it/s]
#
#
#
#   5%|▌         | 515/10000 [01:20<23:41,  6.67it/s]
#
#
#
#   5%|▌         | 516/10000 [01:20<23:34,  6.70it/s]
#
#
#
#   5%|▌         | 517/10000 [01:20<23:34,  6.70it/s]
#
#
#
#   5%|▌         | 518/10000 [01:20<23:39,  6.68it/s]
#
#
#
#   5%|▌         | 519/10000 [01:20<23:31,  6.72it/s]
#
#
#
#   5%|▌         | 520/10000 [01:20<23:41,  6.67it/s]
#
#
#
#   5%|▌         | 521/10000 [01:20<23:36,  6.69it/s]
#
#
#
#   5%|▌         | 522/10000 [01:21<23:46,  6.64it/s]
#
#
#
#   5%|▌         | 523/10000 [01:21<23:36,  6.69it/s]
#
#
#
#   5%|▌         | 524/10000 [01:21<23:32,  6.71it/s]
#
#
#
#   5%|▌         | 525/10000 [01:21<23:36,  6.69it/s]
#
#
#
#   5%|▌         | 526/10000 [01:21<23:45,  6.65it/s]
#
#
#
#   5%|▌         | 527/10000 [01:21<24:13,  6.52it/s]
#
#
#
#   5%|▌         | 528/10000 [01:21<24:28,  6.45it/s]
#
#
#
#   5%|▌         | 529/10000 [01:22<25:31,  6.19it/s]
#
#
#
#   5%|▌         | 530/10000 [01:22<25:38,  6.15it/s]
#
#
#
#   5%|▌         | 531/10000 [01:22<25:47,  6.12it/s]
#
#
#
#   5%|▌         | 532/10000 [01:22<25:33,  6.18it/s]
#
#
#
#   5%|▌         | 533/10000 [01:22<25:26,  6.20it/s]
#
#
#
#   5%|▌         | 534/10000 [01:22<25:06,  6.28it/s]
#
#
#
#   5%|▌         | 535/10000 [01:23<25:17,  6.24it/s]
#
#
#
#   5%|▌         | 536/10000 [01:23<25:15,  6.24it/s]
#
#
#
#   5%|▌         | 537/10000 [01:23<25:58,  6.07it/s]
#
#
#
#   5%|▌         | 538/10000 [01:23<26:03,  6.05it/s]
#
#
#
#   5%|▌         | 539/10000 [01:23<26:54,  5.86it/s]
#
#
#
#   5%|▌         | 540/10000 [01:23<26:07,  6.04it/s]
#
#
#
#   5%|▌         | 541/10000 [01:24<27:02,  5.83it/s]
#
#
#
#   5%|▌         | 542/10000 [01:24<28:06,  5.61it/s]
#
#
#
#   5%|▌         | 543/10000 [01:24<29:20,  5.37it/s]
#
#
#
#   5%|▌         | 544/10000 [01:24<29:01,  5.43it/s]
#
#
#
#   5%|▌         | 545/10000 [01:24<28:50,  5.46it/s]
#
#
#
#   5%|▌         | 546/10000 [01:25<29:42,  5.30it/s]
#
#
#
#   5%|▌         | 547/10000 [01:25<32:00,  4.92it/s]
#
#
#
#   5%|▌         | 548/10000 [01:25<31:02,  5.07it/s]
#
#
#
#   5%|▌         | 549/10000 [01:25<29:54,  5.27it/s]
#
#
#
#   6%|▌         | 550/10000 [01:25<29:10,  5.40it/s]
#
#
#
#   6%|▌         | 551/10000 [01:26<29:27,  5.34it/s]
#
#
#
#   6%|▌         | 552/10000 [01:26<28:58,  5.43it/s]
#
#
#
#   6%|▌         | 553/10000 [01:26<28:26,  5.54it/s]
#
#
#
#   6%|▌         | 554/10000 [01:26<27:51,  5.65it/s]
#
#
#
#   6%|▌         | 555/10000 [01:26<27:14,  5.78it/s]
#
#
#
#   6%|▌         | 556/10000 [01:26<26:44,  5.88it/s]
#
#
#
#   6%|▌         | 557/10000 [01:27<26:23,  5.96it/s]
#
#
#
#   6%|▌         | 558/10000 [01:27<25:53,  6.08it/s]
#
#
#
#   6%|▌         | 559/10000 [01:27<25:30,  6.17it/s]
#
#
#
#   6%|▌         | 560/10000 [01:27<25:11,  6.25it/s]
#
#
#
#   6%|▌         | 561/10000 [01:27<24:58,  6.30it/s]
#
#
#
#   6%|▌         | 562/10000 [01:27<24:51,  6.33it/s]
#
#
#
#   6%|▌         | 563/10000 [01:28<24:42,  6.37it/s]
#
#
#
#   6%|▌         | 564/10000 [01:28<24:24,  6.44it/s]
#
#
#
#   6%|▌         | 565/10000 [01:28<24:19,  6.46it/s]
#
#
#
#   6%|▌         | 566/10000 [01:28<24:03,  6.53it/s]
#
#
#
#   6%|▌         | 567/10000 [01:28<23:55,  6.57it/s]
#
#
#
#   6%|▌         | 568/10000 [01:28<23:44,  6.62it/s]
#
#
#
#   6%|▌         | 569/10000 [01:28<23:42,  6.63it/s]
#
#
#
#   6%|▌         | 570/10000 [01:29<23:37,  6.65it/s]
#
#
#
#   6%|▌         | 571/10000 [01:29<23:37,  6.65it/s]
#
#
#
#   6%|▌         | 572/10000 [01:29<23:27,  6.70it/s]
#
#
#
#   6%|▌         | 573/10000 [01:29<23:25,  6.71it/s]
#
#
#
#   6%|▌         | 574/10000 [01:29<23:25,  6.71it/s]
#
#
#
#   6%|▌         | 575/10000 [01:29<23:30,  6.68it/s]
#
#
#
#   6%|▌         | 576/10000 [01:29<23:27,  6.69it/s]
#
#
#
#   6%|▌         | 577/10000 [01:30<23:32,  6.67it/s]
#
#
#
#   6%|▌         | 578/10000 [01:30<23:26,  6.70it/s]
#
#
#
#   6%|▌         | 579/10000 [01:30<23:32,  6.67it/s]
#
#
#
#   6%|▌         | 580/10000 [01:30<23:29,  6.68it/s]
#
#
#
#   6%|▌         | 581/10000 [01:30<23:36,  6.65it/s]
#
#
#
#   6%|▌         | 582/10000 [01:30<23:30,  6.68it/s]
#
#
#
#   6%|▌         | 583/10000 [01:31<24:31,  6.40it/s]
#
#
#
#   6%|▌         | 584/10000 [01:31<24:01,  6.53it/s]
#
#
#
#   6%|▌         | 585/10000 [01:31<23:57,  6.55it/s]
#
#
#
#   6%|▌         | 586/10000 [01:31<23:41,  6.62it/s]
#
#
#
#   6%|▌         | 587/10000 [01:31<24:00,  6.53it/s]
#
#
#
#   6%|▌         | 588/10000 [01:31<23:39,  6.63it/s]
#
#
#
#   6%|▌         | 589/10000 [01:31<23:36,  6.65it/s]
#
#
#
#   6%|▌         | 590/10000 [01:32<23:30,  6.67it/s]
#
#
#
#   6%|▌         | 591/10000 [01:32<23:17,  6.73it/s]
#
#
#
#   6%|▌         | 592/10000 [01:32<23:17,  6.73it/s]
#
#
#
#   6%|▌         | 593/10000 [01:32<23:18,  6.73it/s]
#
#
#
#   6%|▌         | 594/10000 [01:32<23:17,  6.73it/s]
#
#
#
#   6%|▌         | 595/10000 [01:32<23:16,  6.73it/s]
#
#
#
#   6%|▌         | 596/10000 [01:32<23:22,  6.70it/s]
#
#
#
#   6%|▌         | 597/10000 [01:33<23:20,  6.71it/s]
#
#
#
#   6%|▌         | 598/10000 [01:33<23:11,  6.76it/s]
#
#
#
#   6%|▌         | 599/10000 [01:33<23:05,  6.78it/s]
#
#
#
#   6%|▌         | 600/10000 [01:33<23:11,  6.76it/s]
#
#
#
#   6%|▌         | 601/10000 [01:33<23:12,  6.75it/s]
#
#
#
#   6%|▌         | 602/10000 [01:33<23:07,  6.77it/s]
#
#
#
#   6%|▌         | 603/10000 [01:34<23:11,  6.76it/s]
#
#
#
#   6%|▌         | 604/10000 [01:34<23:01,  6.80it/s]
#
#
#
#   6%|▌         | 605/10000 [01:34<22:54,  6.84it/s]
#
#
#
#   6%|▌         | 606/10000 [01:34<22:53,  6.84it/s]
#
#
#
#   6%|▌         | 607/10000 [01:34<22:52,  6.84it/s]
#
#
#
#   6%|▌         | 608/10000 [01:34<22:50,  6.85it/s]
#
#
#
#   6%|▌         | 609/10000 [01:34<22:57,  6.82it/s]
#
#
#
#   6%|▌         | 610/10000 [01:35<22:54,  6.83it/s]
#
#
#
#   6%|▌         | 611/10000 [01:35<23:19,  6.71it/s]
#
#
#
#   6%|▌         | 612/10000 [01:35<23:10,  6.75it/s]
#
#
#
#   6%|▌         | 613/10000 [01:35<24:12,  6.46it/s]
#
#
#
#   6%|▌         | 614/10000 [01:35<23:41,  6.60it/s]
#
#
#
#   6%|▌         | 615/10000 [01:35<23:34,  6.64it/s]
#
#
#
#   6%|▌         | 616/10000 [01:35<23:51,  6.56it/s]
#
#
#
#   6%|▌         | 617/10000 [01:36<23:35,  6.63it/s]
#
#
#
#   6%|▌         | 618/10000 [01:36<23:35,  6.63it/s]
#
#
#
#   6%|▌         | 619/10000 [01:36<23:36,  6.62it/s]
#
#
#
#   6%|▌         | 620/10000 [01:36<23:34,  6.63it/s]
#
#
#
#   6%|▌         | 621/10000 [01:36<23:30,  6.65it/s]
#
#
#
#   6%|▌         | 622/10000 [01:36<23:22,  6.69it/s]
#
#
#
#   6%|▌         | 623/10000 [01:37<23:47,  6.57it/s]
#
#
#
#   6%|▌         | 624/10000 [01:37<23:39,  6.61it/s]
#
#
#
#   6%|▋         | 625/10000 [01:37<23:30,  6.65it/s]
#
#
#
#   6%|▋         | 626/10000 [01:37<23:39,  6.60it/s]
#
#
#
#   6%|▋         | 627/10000 [01:37<23:25,  6.67it/s]
#
#
#
#   6%|▋         | 628/10000 [01:37<24:00,  6.50it/s]
#
#
#
#   6%|▋         | 629/10000 [01:37<23:59,  6.51it/s]
#
#
#
#   6%|▋         | 630/10000 [01:38<24:01,  6.50it/s]
#
#
#
#   6%|▋         | 631/10000 [01:38<23:54,  6.53it/s]
#
#
#
#   6%|▋         | 632/10000 [01:38<24:18,  6.42it/s]
#
#
#
#   6%|▋         | 633/10000 [01:38<25:05,  6.22it/s]
#
#
#
#   6%|▋         | 634/10000 [01:38<24:56,  6.26it/s]
#
#
#
#   6%|▋         | 635/10000 [01:38<25:12,  6.19it/s]
#
#
#
#   6%|▋         | 636/10000 [01:39<25:33,  6.11it/s]
#
#
#
#   6%|▋         | 637/10000 [01:39<25:59,  6.00it/s]
#
#
#
#   6%|▋         | 638/10000 [01:39<25:42,  6.07it/s]
#
#
#
#   6%|▋         | 639/10000 [01:39<25:53,  6.03it/s]
#
#
#
#   6%|▋         | 640/10000 [01:39<25:51,  6.03it/s]
#
#
#
#   6%|▋         | 641/10000 [01:39<25:55,  6.02it/s]
#
#
#
#   6%|▋         | 642/10000 [01:40<25:36,  6.09it/s]
#
#
#
#   6%|▋         | 643/10000 [01:40<25:47,  6.04it/s]
#
#
#
#   6%|▋         | 644/10000 [01:40<25:56,  6.01it/s]
#
#
#
#   6%|▋         | 645/10000 [01:40<25:44,  6.06it/s]
#
#
#
#   6%|▋         | 646/10000 [01:40<25:40,  6.07it/s]
#
#
#
#   6%|▋         | 647/10000 [01:40<25:55,  6.01it/s]
#
#
#
#   6%|▋         | 648/10000 [01:41<25:57,  6.00it/s]
#
#
#
#   6%|▋         | 649/10000 [01:41<25:41,  6.07it/s]
#
#
#
#   6%|▋         | 650/10000 [01:41<25:25,  6.13it/s]
#
#
#
#   7%|▋         | 651/10000 [01:41<25:15,  6.17it/s]
#
#
#
#   7%|▋         | 652/10000 [01:41<25:00,  6.23it/s]
#
#
#
#   7%|▋         | 653/10000 [01:41<25:02,  6.22it/s]
#
#
#
#   7%|▋         | 654/10000 [01:41<24:41,  6.31it/s]
#
#
#
#   7%|▋         | 655/10000 [01:42<24:20,  6.40it/s]
#
#
#
#   7%|▋         | 656/10000 [01:42<23:59,  6.49it/s]
#
#
#
#   7%|▋         | 657/10000 [01:42<23:55,  6.51it/s]
#
#
#
#   7%|▋         | 658/10000 [01:42<23:44,  6.56it/s]
#
#
#
#   7%|▋         | 659/10000 [01:42<24:26,  6.37it/s]
#
#
#
#   7%|▋         | 660/10000 [01:42<24:09,  6.45it/s]
#
#
#
#   7%|▋         | 661/10000 [01:43<24:05,  6.46it/s]
#
#
#
#   7%|▋         | 662/10000 [01:43<23:50,  6.53it/s]
#
#
#
#   7%|▋         | 663/10000 [01:43<23:36,  6.59it/s]
#
#
#
#   7%|▋         | 664/10000 [01:43<23:19,  6.67it/s]
#
#
#
#   7%|▋         | 665/10000 [01:43<23:13,  6.70it/s]
#
#
#
#   7%|▋         | 666/10000 [01:43<23:09,  6.72it/s]
#
#
#
#   7%|▋         | 667/10000 [01:43<23:16,  6.69it/s]
#
#
#
#   7%|▋         | 668/10000 [01:44<23:10,  6.71it/s]
#
#
#
#   7%|▋         | 669/10000 [01:44<23:14,  6.69it/s]
#
#
#
#   7%|▋         | 670/10000 [01:44<23:07,  6.72it/s]
#
#
#
#   7%|▋         | 671/10000 [01:44<23:03,  6.74it/s]
#
#
#
#   7%|▋         | 672/10000 [01:44<23:10,  6.71it/s]
#
#
#
#   7%|▋         | 673/10000 [01:44<23:07,  6.72it/s]
#
#
#
#   7%|▋         | 674/10000 [01:45<23:04,  6.74it/s]
#
#
#
#   7%|▋         | 675/10000 [01:45<23:01,  6.75it/s]
#
#
#
#   7%|▋         | 676/10000 [01:45<23:08,  6.71it/s]
#
#
#
#   7%|▋         | 677/10000 [01:45<23:27,  6.62it/s]
#
#
#
#   7%|▋         | 678/10000 [01:45<23:19,  6.66it/s]
#
#
#
#   7%|▋         | 679/10000 [01:45<23:23,  6.64it/s]
#
#
#
#   7%|▋         | 680/10000 [01:45<23:19,  6.66it/s]
#
#
#
#   7%|▋         | 681/10000 [01:46<23:12,  6.69it/s]
#
#
#
#   7%|▋         | 682/10000 [01:46<23:10,  6.70it/s]
#
#
#
#   7%|▋         | 683/10000 [01:46<23:06,  6.72it/s]
#
#
#
#   7%|▋         | 684/10000 [01:46<23:02,  6.74it/s]
#
#
#
#   7%|▋         | 685/10000 [01:46<23:09,  6.71it/s]
#
#
#
#   7%|▋         | 686/10000 [01:46<23:09,  6.70it/s]
#
#
#
#   7%|▋         | 687/10000 [01:46<23:14,  6.68it/s]
#
#
#
#   7%|▋         | 688/10000 [01:47<23:18,  6.66it/s]
#
#
#
#   7%|▋         | 689/10000 [01:47<23:32,  6.59it/s]
#
#
#
#   7%|▋         | 690/10000 [01:47<23:25,  6.63it/s]
#
#
#
#   7%|▋         | 691/10000 [01:47<23:21,  6.64it/s]
#
#
#
#   7%|▋         | 692/10000 [01:47<23:24,  6.63it/s]
#
#
#
#   7%|▋         | 693/10000 [01:47<23:22,  6.63it/s]
#
#
#
#   7%|▋         | 694/10000 [01:48<23:32,  6.59it/s]
#
#
#
#   7%|▋         | 695/10000 [01:48<23:30,  6.60it/s]
#
#
#
#   7%|▋         | 696/10000 [01:48<23:19,  6.65it/s]
#
#
#
#   7%|▋         | 697/10000 [01:48<23:15,  6.67it/s]
#
#
#
#   7%|▋         | 698/10000 [01:48<23:08,  6.70it/s]
#
#
#
#   7%|▋         | 699/10000 [01:48<23:19,  6.65it/s]
#
#
#
#   7%|▋         | 700/10000 [01:48<23:19,  6.65it/s]
#
#
#
#   7%|▋         | 701/10000 [01:49<23:20,  6.64it/s]
#
#
#
#   7%|▋         | 702/10000 [01:49<25:28,  6.08it/s]
#
#
#
#   7%|▋         | 703/10000 [01:49<25:31,  6.07it/s]
#
#
#
#   7%|▋         | 704/10000 [01:49<25:25,  6.09it/s]
#
#
#
#   7%|▋         | 705/10000 [01:49<24:52,  6.23it/s]
#
#
#
#   7%|▋         | 706/10000 [01:49<24:11,  6.40it/s]
#
#
#
#   7%|▋         | 707/10000 [01:50<23:39,  6.55it/s]
#
#
#
#   7%|▋         | 708/10000 [01:50<23:17,  6.65it/s]
#
#
#
#   7%|▋         | 709/10000 [01:50<23:16,  6.65it/s]
#
#
#
#   7%|▋         | 710/10000 [01:50<23:07,  6.69it/s]
#
#
#
#   7%|▋         | 711/10000 [01:50<23:05,  6.71it/s]
#
#
#
#   7%|▋         | 712/10000 [01:50<23:03,  6.71it/s]
#
#
#
#   7%|▋         | 713/10000 [01:50<23:01,  6.72it/s]
#
#
#
#   7%|▋         | 714/10000 [01:51<22:54,  6.76it/s]
#
#
#
#   7%|▋         | 715/10000 [01:51<22:53,  6.76it/s]
#
#
#
#   7%|▋         | 716/10000 [01:51<22:47,  6.79it/s]
#
#
#
#   7%|▋         | 717/10000 [01:51<22:47,  6.79it/s]
#
#
#
#   7%|▋         | 718/10000 [01:51<22:39,  6.83it/s]
#
#
#
#   7%|▋         | 719/10000 [01:51<22:40,  6.82it/s]
#
#
#
#   7%|▋         | 720/10000 [01:51<22:36,  6.84it/s]
#
#
#
#   7%|▋         | 721/10000 [01:52<22:47,  6.79it/s]
#
#
#
#   7%|▋         | 722/10000 [01:52<22:44,  6.80it/s]
#
#
#
#   7%|▋         | 723/10000 [01:52<22:56,  6.74it/s]
#
#
#
#   7%|▋         | 724/10000 [01:52<23:23,  6.61it/s]
#
#
#
#   7%|▋         | 725/10000 [01:52<23:23,  6.61it/s]
#
#
#
#   7%|▋         | 726/10000 [01:52<23:16,  6.64it/s]
#
#
#
#   7%|▋         | 727/10000 [01:52<23:10,  6.67it/s]
#
#
#
#   7%|▋         | 728/10000 [01:53<23:01,  6.71it/s]
#
#
#
#   7%|▋         | 729/10000 [01:53<23:02,  6.71it/s]
#
#
#
#   7%|▋         | 730/10000 [01:53<22:59,  6.72it/s]
#
#
#
#   7%|▋         | 731/10000 [01:53<23:04,  6.69it/s]
#
#
#
#   7%|▋         | 732/10000 [01:53<23:14,  6.65it/s]
#
#
#
#   7%|▋         | 733/10000 [01:53<23:22,  6.61it/s]
#   7%|▋         | 734/10000 [01:54<23:22,  6.61it/s]
#
#
#
#   7%|▋         | 735/10000 [01:54<23:24,  6.60it/s]
#
#
#
#   7%|▋         | 736/10000 [01:54<23:19,  6.62it/s]
#
#
#
#   7%|▋         | 737/10000 [01:54<23:14,  6.64it/s]
#
#
#
#   7%|▋         | 738/10000 [01:54<23:13,  6.64it/s]
#
#
#
#   7%|▋         | 739/10000 [01:54<23:21,  6.61it/s]
#
#
#
#   7%|▋         | 740/10000 [01:54<23:22,  6.60it/s]
#
#
#
#   7%|▋         | 741/10000 [01:55<23:26,  6.58it/s]
#
#
#
#   7%|▋         | 742/10000 [01:55<23:17,  6.63it/s]
#
#
#
#   7%|▋         | 743/10000 [01:55<23:16,  6.63it/s]
#
#
#
#   7%|▋         | 744/10000 [01:55<23:12,  6.65it/s]
#
#
#
#   7%|▋         | 745/10000 [01:55<23:14,  6.63it/s]
#
#
#
#   7%|▋         | 746/10000 [01:55<23:15,  6.63it/s]
#
#
#
#   7%|▋         | 747/10000 [01:56<23:18,  6.62it/s]
#
#
#
#   7%|▋         | 748/10000 [01:56<23:16,  6.62it/s]
#
#
#
#   7%|▋         | 749/10000 [01:56<23:16,  6.62it/s]
#
#
#
#   8%|▊         | 750/10000 [01:56<23:15,  6.63it/s]
#
#
#
#   8%|▊         | 751/10000 [01:56<23:14,  6.63it/s]
#
#
#
#   8%|▊         | 752/10000 [01:56<23:16,  6.62it/s]
#
#
#
#   8%|▊         | 753/10000 [01:56<23:22,  6.59it/s]
#
#
#
#   8%|▊         | 754/10000 [01:57<23:19,  6.60it/s]
#
#
#
#   8%|▊         | 755/10000 [01:57<23:19,  6.60it/s]
#
#
#
#   8%|▊         | 756/10000 [01:57<23:20,  6.60it/s]
#
#
#
#   8%|▊         | 757/10000 [01:57<23:26,  6.57it/s]
#
#
#
#   8%|▊         | 758/10000 [01:57<23:24,  6.58it/s]
#
#
#
#   8%|▊         | 759/10000 [01:57<23:19,  6.60it/s]
#
#
#
#   8%|▊         | 760/10000 [01:57<23:17,  6.61it/s]
#
#
#
#   8%|▊         | 761/10000 [01:58<23:19,  6.60it/s]
#
#
#
#   8%|▊         | 762/10000 [01:58<23:19,  6.60it/s]
#
#
#
#   8%|▊         | 763/10000 [01:58<23:16,  6.62it/s]
#
#
#
#   8%|▊         | 764/10000 [01:58<23:14,  6.62it/s]
#
#
#
#   8%|▊         | 765/10000 [01:58<23:14,  6.62it/s]
#
#
#
#   8%|▊         | 766/10000 [01:58<23:11,  6.64it/s]
#
#
#
#   8%|▊         | 767/10000 [01:59<23:08,  6.65it/s]
#
#
#
#   8%|▊         | 768/10000 [01:59<23:05,  6.66it/s]
#
#
#
#   8%|▊         | 769/10000 [01:59<23:03,  6.67it/s]
#
#
#
#   8%|▊         | 770/10000 [01:59<23:02,  6.68it/s]
#
#
#
#   8%|▊         | 771/10000 [01:59<23:04,  6.67it/s]
#
#
#
#   8%|▊         | 772/10000 [01:59<23:03,  6.67it/s]
#
#
#
#   8%|▊         | 773/10000 [01:59<23:08,  6.65it/s]
#
#
#
#   8%|▊         | 774/10000 [02:00<23:09,  6.64it/s]
#
#
#
#   8%|▊         | 775/10000 [02:00<23:27,  6.56it/s]
#
#
#
#   8%|▊         | 776/10000 [02:00<23:28,  6.55it/s]
#
#
#
#   8%|▊         | 777/10000 [02:00<23:33,  6.53it/s]
#
#
#
#   8%|▊         | 778/10000 [02:00<23:42,  6.48it/s]
#
#
#
#   8%|▊         | 779/10000 [02:00<23:56,  6.42it/s]
#
#
#
#   8%|▊         | 780/10000 [02:01<24:03,  6.39it/s]
#
#
#
#   8%|▊         | 781/10000 [02:01<24:00,  6.40it/s]
#
#
#
#   8%|▊         | 782/10000 [02:01<24:07,  6.37it/s]
#
#
#
#   8%|▊         | 783/10000 [02:01<24:15,  6.33it/s]
#
#
#
#   8%|▊         | 784/10000 [02:01<24:28,  6.27it/s]
#
#
#
#   8%|▊         | 785/10000 [02:01<24:26,  6.28it/s]
#
#
#
#   8%|▊         | 786/10000 [02:01<24:27,  6.28it/s]
#
#
#
#   8%|▊         | 787/10000 [02:02<24:28,  6.27it/s]
#
#
#
#   8%|▊         | 788/10000 [02:02<24:27,  6.28it/s]
#
#
#
#   8%|▊         | 789/10000 [02:02<24:27,  6.28it/s]
#
#
#
#   8%|▊         | 790/10000 [02:02<25:05,  6.12it/s]
#
#
#
#   8%|▊         | 791/10000 [02:02<25:21,  6.05it/s]
#
#
#
#   8%|▊         | 792/10000 [02:02<25:15,  6.08it/s]
#
#
#
#   8%|▊         | 793/10000 [02:03<25:04,  6.12it/s]
#
#
#
#   8%|▊         | 794/10000 [02:03<25:03,  6.12it/s]
#
#
#
#   8%|▊         | 795/10000 [02:03<24:55,  6.15it/s]
#
#
#
#   8%|▊         | 796/10000 [02:03<24:49,  6.18it/s]
#
#
#
#   8%|▊         | 797/10000 [02:03<24:58,  6.14it/s]
#
#
#
#   8%|▊         | 798/10000 [02:03<24:44,  6.20it/s]
#
#
#
#   8%|▊         | 799/10000 [02:04<24:37,  6.23it/s]
#
#
#
#   8%|▊         | 800/10000 [02:04<24:27,  6.27it/s]
#
#
#
#   8%|▊         | 801/10000 [02:04<24:59,  6.14it/s]
#
#
#
#   8%|▊         | 802/10000 [02:04<25:57,  5.90it/s]
#
#
#
#   8%|▊         | 803/10000 [02:04<26:09,  5.86it/s]
#
#
#
#   8%|▊         | 804/10000 [02:04<26:28,  5.79it/s]
#
#
#
#   8%|▊         | 805/10000 [02:05<26:35,  5.76it/s]
#
#
#
#   8%|▊         | 806/10000 [02:05<26:08,  5.86it/s]
#
#
#
#   8%|▊         | 807/10000 [02:05<25:54,  5.91it/s]
#
#
#
#   8%|▊         | 808/10000 [02:05<25:53,  5.92it/s]
#
#
#
#   8%|▊         | 809/10000 [02:05<26:01,  5.89it/s]
#
#
#
#   8%|▊         | 810/10000 [02:05<26:17,  5.83it/s]
#
#
#
#   8%|▊         | 811/10000 [02:06<26:11,  5.85it/s]
#
#
#
#   8%|▊         | 812/10000 [02:06<25:50,  5.93it/s]
#
#
#
#   8%|▊         | 813/10000 [02:06<25:51,  5.92it/s]
#
#
#
#   8%|▊         | 814/10000 [02:06<26:40,  5.74it/s]
#
#
#
# ...
#
#
#
#  22%|██▏       | 2196/10000 [05:42<19:41,  6.60it/s]
#
#
#
#  22%|██▏       | 2197/10000 [05:42<19:34,  6.65it/s]
#
#
#
#  22%|██▏       | 2198/10000 [05:42<19:40,  6.61it/s]
#
#
#
#  22%|██▏       | 2199/10000 [05:43<19:36,  6.63it/s]
#
#
#
#  22%|██▏       | 2200/10000 [05:43<19:30,  6.67it/s]
#
#
#
#  22%|██▏       | 2201/10000 [05:43<19:18,  6.73it/s]
#
#
#
#  22%|██▏       | 2202/10000 [05:43<19:11,  6.77it/s]
#
#
#
#  22%|██▏       | 2203/10000 [05:43<19:18,  6.73it/s]
#
#
#
#  22%|██▏       | 2204/10000 [05:43<19:08,  6.79it/s]
#
#
#
#  22%|██▏       | 2205/10000 [05:44<19:06,  6.80it/s]
#
#
#
#  22%|██▏       | 2206/10000 [05:44<19:01,  6.83it/s]
#
#
#
#  22%|██▏       | 2207/10000 [05:44<19:01,  6.83it/s]
#
#
#
#  22%|██▏       | 2208/10000 [05:44<18:57,  6.85it/s]
#
#
#
#  22%|██▏       | 2209/10000 [05:44<19:00,  6.83it/s]
#
#
#
#  22%|██▏       | 2210/10000 [05:44<18:58,  6.85it/s]
#
#
#
#  22%|██▏       | 2211/10000 [05:44<19:04,  6.81it/s]
#
#
#
#  22%|██▏       | 2212/10000 [05:45<19:00,  6.83it/s]
#
#
#
#  22%|██▏       | 2213/10000 [05:45<18:59,  6.83it/s]
#
#
#
#  22%|██▏       | 2214/10000 [05:45<18:55,  6.86it/s]
#
#
#
#  22%|██▏       | 2215/10000 [05:45<18:57,  6.85it/s]
#
#
#
#  22%|██▏       | 2216/10000 [05:45<19:06,  6.79it/s]
#
#
#
#  22%|██▏       | 2217/10000 [05:45<19:03,  6.81it/s]
#
#
#
#  22%|██▏       | 2218/10000 [05:45<18:59,  6.83it/s]
#
#
#
#  22%|██▏       | 2219/10000 [05:46<19:00,  6.82it/s]
#
#
#
#  22%|██▏       | 2220/10000 [05:46<19:08,  6.78it/s]
#
#
#
#  22%|██▏       | 2221/10000 [05:46<19:16,  6.73it/s]
#
#
#
#  22%|██▏       | 2222/10000 [05:46<19:15,  6.73it/s]
#
#
#
#  22%|██▏       | 2223/10000 [05:46<19:18,  6.71it/s]
#
#
#
#  22%|██▏       | 2224/10000 [05:46<19:11,  6.75it/s]
#
#
#
#  22%|██▏       | 2225/10000 [05:46<19:09,  6.76it/s]
#
#
#
#  22%|██▏       | 2226/10000 [05:47<18:59,  6.82it/s]
#
#
#
#  22%|██▏       | 2227/10000 [05:47<19:09,  6.76it/s]
#
#
#
#  22%|██▏       | 2228/10000 [05:47<19:10,  6.76it/s]
#
#
#
#  22%|██▏       | 2229/10000 [05:47<19:06,  6.78it/s]
#
#
#
#  22%|██▏       | 2230/10000 [05:47<19:04,  6.79it/s]
#
#
#
#  22%|██▏       | 2231/10000 [05:47<19:04,  6.79it/s]
#
#
#
#  22%|██▏       | 2232/10000 [05:47<18:52,  6.86it/s]
#
#
#
#  22%|██▏       | 2233/10000 [05:48<18:47,  6.89it/s]
#
#
#
#  22%|██▏       | 2234/10000 [05:48<18:53,  6.85it/s]
#
#
#
#  22%|██▏       | 2235/10000 [05:48<18:59,  6.81it/s]
#
#
#
#  22%|██▏       | 2236/10000 [05:48<18:55,  6.84it/s]
#
#
#
#  22%|██▏       | 2237/10000 [05:48<18:55,  6.84it/s]
#
#
#
#  22%|██▏       | 2238/10000 [05:48<18:46,  6.89it/s]
#
#
#
#  22%|██▏       | 2239/10000 [05:49<18:53,  6.85it/s]
#
#
#
#  22%|██▏       | 2240/10000 [05:49<18:44,  6.90it/s]
#
#
#
#  22%|██▏       | 2241/10000 [05:49<18:40,  6.92it/s]
#
#
#
#  22%|██▏       | 2242/10000 [05:49<19:06,  6.77it/s]
#
#
#
#  22%|██▏       | 2243/10000 [05:49<18:59,  6.81it/s]
#
#
#
#  22%|██▏       | 2244/10000 [05:49<18:57,  6.82it/s]
#
#
#
#  22%|██▏       | 2245/10000 [05:49<18:56,  6.82it/s]
#
#
#
#  22%|██▏       | 2246/10000 [05:50<18:56,  6.82it/s]
#
#
#
#  22%|██▏       | 2247/10000 [05:50<18:50,  6.86it/s]
#
#
#
#  22%|██▏       | 2248/10000 [05:50<18:54,  6.84it/s]
#
#
#
#  22%|██▏       | 2249/10000 [05:50<18:59,  6.80it/s]
#
#
#
#  22%|██▎       | 2250/10000 [05:50<19:13,  6.72it/s]
#
#
#
#  23%|██▎       | 2251/10000 [05:50<19:02,  6.78it/s]
#
#
#
#  23%|██▎       | 2252/10000 [05:50<18:53,  6.84it/s]
#
#
#
#  23%|██▎       | 2253/10000 [05:51<18:44,  6.89it/s]
#
#
#
#  23%|██▎       | 2254/10000 [05:51<18:37,  6.93it/s]
#
#
#
#  23%|██▎       | 2255/10000 [05:51<18:37,  6.93it/s]
#
#
#
#  23%|██▎       | 2256/10000 [05:51<18:36,  6.94it/s]
#
#
#
#  23%|██▎       | 2257/10000 [05:51<18:34,  6.95it/s]
#
#
#
#  23%|██▎       | 2258/10000 [05:51<18:36,  6.93it/s]
#
#
#
#  23%|██▎       | 2259/10000 [05:51<18:43,  6.89it/s]
#
#
#
#  23%|██▎       | 2260/10000 [05:52<18:45,  6.87it/s]
#
#
#
#  23%|██▎       | 2261/10000 [05:52<18:54,  6.82it/s]
#
#
#
#  23%|██▎       | 2262/10000 [05:52<18:49,  6.85it/s]
#
#
#
#  23%|██▎       | 2263/10000 [05:52<18:43,  6.89it/s]
#
#
#
#  23%|██▎       | 2264/10000 [05:52<19:06,  6.75it/s]
#
#
#
#  23%|██▎       | 2265/10000 [05:52<19:23,  6.65it/s]
#
#
#
#  23%|██▎       | 2266/10000 [05:52<19:07,  6.74it/s]
#
#
#
#  23%|██▎       | 2267/10000 [05:53<18:56,  6.80it/s]
#
#
#
#  23%|██▎       | 2268/10000 [05:53<18:50,  6.84it/s]
#
#
#
#  23%|██▎       | 2269/10000 [05:53<18:48,  6.85it/s]
#
#
#
#  23%|██▎       | 2270/10000 [05:53<18:43,  6.88it/s]
#
#
#
#  23%|██▎       | 2271/10000 [05:53<18:45,  6.87it/s]
#
#
#
#  23%|██▎       | 2272/10000 [05:53<18:52,  6.83it/s]
#
#
#
#  23%|██▎       | 2273/10000 [05:53<18:48,  6.85it/s]
#
#
#
#  23%|██▎       | 2274/10000 [05:54<18:52,  6.82it/s]
#
#
#
#  23%|██▎       | 2275/10000 [05:54<19:04,  6.75it/s]
#
#
#
#  23%|██▎       | 2276/10000 [05:54<19:10,  6.72it/s]
#
#
#
#  23%|██▎       | 2277/10000 [05:54<19:14,  6.69it/s]
#
#
#
#  23%|██▎       | 2278/10000 [05:54<19:34,  6.58it/s]
#
#
#
#  23%|██▎       | 2279/10000 [05:54<20:24,  6.30it/s]
#
#
#
#  23%|██▎       | 2280/10000 [05:55<20:05,  6.40it/s]
#
#
#
#  23%|██▎       | 2281/10000 [05:55<19:45,  6.51it/s]
#
#
#
#  23%|██▎       | 2282/10000 [05:55<19:29,  6.60it/s]
#
#
#
#  23%|██▎       | 2283/10000 [05:55<19:56,  6.45it/s]
#
#
#
#  23%|██▎       | 2284/10000 [05:55<20:25,  6.29it/s]
#
#
#
#  23%|██▎       | 2285/10000 [05:55<20:04,  6.40it/s]
#
#
#
#  23%|██▎       | 2286/10000 [05:55<19:55,  6.45it/s]
#
#
#
#  23%|██▎       | 2287/10000 [05:56<19:32,  6.58it/s]
#
#
#
#  23%|██▎       | 2288/10000 [05:56<19:24,  6.62it/s]
#
#
#
#  23%|██▎       | 2289/10000 [05:56<19:20,  6.64it/s]
#
#
#
#  23%|██▎       | 2290/10000 [05:56<19:09,  6.71it/s]
#
#
#
#  23%|██▎       | 2291/10000 [05:56<18:58,  6.77it/s]
#
#
#
#  23%|██▎       | 2292/10000 [05:56<18:58,  6.77it/s]
#
#
#
#  23%|██▎       | 2293/10000 [05:57<18:55,  6.79it/s]
#
#
#
#  23%|██▎       | 2294/10000 [05:57<19:33,  6.57it/s]
#
#
#
#  23%|██▎       | 2295/10000 [05:57<23:47,  5.40it/s]
#
#
#
#  23%|██▎       | 2296/10000 [05:57<27:31,  4.67it/s]
#
#
#
#  23%|██▎       | 2297/10000 [05:57<28:55,  4.44it/s]
#
#
#
#  23%|██▎       | 2298/10000 [05:58<27:00,  4.75it/s]
#
#
#
#  23%|██▎       | 2299/10000 [05:58<25:31,  5.03it/s]
#
#
#
#  23%|██▎       | 2300/10000 [05:58<24:17,  5.28it/s]
#
#
#
#  23%|██▎       | 2301/10000 [05:58<23:16,  5.51it/s]
#
#
#
#  23%|██▎       | 2302/10000 [05:58<22:55,  5.59it/s]
#
#
#
#  23%|██▎       | 2303/10000 [05:58<22:24,  5.73it/s]
#
#
#
#  23%|██▎       | 2304/10000 [05:59<21:50,  5.87it/s]
#
#
#
#  23%|██▎       | 2305/10000 [05:59<21:34,  5.94it/s]
#
#
#
#  23%|██▎       | 2306/10000 [05:59<21:23,  5.99it/s]
#
#
#
#  23%|██▎       | 2307/10000 [05:59<21:14,  6.03it/s]
#
#
#
#  23%|██▎       | 2308/10000 [05:59<21:09,  6.06it/s]
#
#
#
#  23%|██▎       | 2309/10000 [05:59<21:15,  6.03it/s]
#
#
#
#  23%|██▎       | 2310/10000 [06:00<21:24,  5.99it/s]
#
#
#
#  23%|██▎       | 2311/10000 [06:00<21:24,  5.99it/s]
#
#
#
#  23%|██▎       | 2312/10000 [06:00<21:21,  6.00it/s]
#
#
#
#  23%|██▎       | 2313/10000 [06:00<21:11,  6.04it/s]
#
#
#
#  23%|██▎       | 2314/10000 [06:00<21:06,  6.07it/s]
#
#
#
#  23%|██▎       | 2315/10000 [06:00<21:00,  6.10it/s]
#
#
#
#  23%|██▎       | 2316/10000 [06:01<21:01,  6.09it/s]
#
#
#
#  23%|██▎       | 2317/10000 [06:01<21:11,  6.04it/s]
#
#
#
#  23%|██▎       | 2318/10000 [06:01<21:11,  6.04it/s]
#
#
#
#  23%|██▎       | 2319/10000 [06:01<21:22,  5.99it/s]
#
#
#
#  23%|██▎       | 2320/10000 [06:01<21:22,  5.99it/s]
#
#
#
#  23%|██▎       | 2321/10000 [06:01<21:21,  5.99it/s]
#
#
#
#  23%|██▎       | 2322/10000 [06:02<21:13,  6.03it/s]
#
#
#
#  23%|██▎       | 2323/10000 [06:02<21:13,  6.03it/s]
#
#
#
#  23%|██▎       | 2324/10000 [06:02<21:09,  6.05it/s]
#
#
#
#  23%|██▎       | 2325/10000 [06:02<21:54,  5.84it/s]
#
#
#
#  23%|██▎       | 2326/10000 [06:02<21:37,  5.92it/s]
#
#
#
#  23%|██▎       | 2327/10000 [06:02<21:23,  5.98it/s]
#
#
#
#  23%|██▎       | 2328/10000 [06:03<21:09,  6.05it/s]
#
#
#
#  23%|██▎       | 2329/10000 [06:03<21:13,  6.02it/s]
#
#
#
#  23%|██▎       | 2330/10000 [06:03<21:29,  5.95it/s]
#
#
#
#  23%|██▎       | 2331/10000 [06:03<21:24,  5.97it/s]
#
#
#
#  23%|██▎       | 2332/10000 [06:03<21:48,  5.86it/s]
#
#
#
#  23%|██▎       | 2333/10000 [06:04<22:40,  5.64it/s]
#
#
#
#  23%|██▎       | 2334/10000 [06:04<22:12,  5.75it/s]
#
#
#
#  23%|██▎       | 2335/10000 [06:04<21:54,  5.83it/s]
#
#
#
#  23%|██▎       | 2336/10000 [06:04<21:42,  5.88it/s]
#
#
#
#  23%|██▎       | 2337/10000 [06:04<21:26,  5.95it/s]
#
#
#
#  23%|██▎       | 2338/10000 [06:04<21:18,  5.99it/s]
#
#
#
#  23%|██▎       | 2339/10000 [06:05<21:17,  6.00it/s]
#
#
#
#  23%|██▎       | 2340/10000 [06:05<21:12,  6.02it/s]
#
#
#
#  23%|██▎       | 2341/10000 [06:05<21:12,  6.02it/s]
#
#
#
#  23%|██▎       | 2342/10000 [06:05<21:10,  6.03it/s]
#
#
#
#  23%|██▎       | 2343/10000 [06:05<21:07,  6.04it/s]
#
#
#
#  23%|██▎       | 2344/10000 [06:05<20:55,  6.10it/s]
#
#
#
#  23%|██▎       | 2345/10000 [06:05<21:05,  6.05it/s]
#
#
#
#  23%|██▎       | 2346/10000 [06:06<21:06,  6.04it/s]
#
#
#
#  23%|██▎       | 2347/10000 [06:06<21:19,  5.98it/s]
#
#
#
#  23%|██▎       | 2348/10000 [06:06<21:30,  5.93it/s]
#
#
#
#  23%|██▎       | 2349/10000 [06:06<21:20,  5.97it/s]
#
#
#
#  24%|██▎       | 2350/10000 [06:06<21:09,  6.02it/s]
#
#
#
#  24%|██▎       | 2351/10000 [06:06<21:06,  6.04it/s]
#
#
#
#  24%|██▎       | 2352/10000 [06:07<21:18,  5.98it/s]
#
#
#
#  24%|██▎       | 2353/10000 [06:07<21:12,  6.01it/s]
#
#
#
#  24%|██▎       | 2354/10000 [06:07<21:09,  6.02it/s]
#
#
#
#  24%|██▎       | 2355/10000 [06:07<21:11,  6.01it/s]
#
#
#
#  24%|██▎       | 2356/10000 [06:07<21:04,  6.04it/s]
#
#
#
#  24%|██▎       | 2357/10000 [06:07<20:59,  6.07it/s]
#
#
#
#  24%|██▎       | 2358/10000 [06:08<23:12,  5.49it/s]
#
#
#
#  24%|██▎       | 2359/10000 [06:08<24:23,  5.22it/s]
#
#
#
#  24%|██▎       | 2360/10000 [06:08<24:25,  5.21it/s]
#
#
#
#  24%|██▎       | 2361/10000 [06:08<23:35,  5.39it/s]
#
#
#
#  24%|██▎       | 2362/10000 [06:08<22:51,  5.57it/s]
#
#
#
#  24%|██▎       | 2363/10000 [06:09<22:26,  5.67it/s]
#
#
#
#  24%|██▎       | 2364/10000 [06:09<22:07,  5.75it/s]
#
#
#
#  24%|██▎       | 2365/10000 [06:09<22:14,  5.72it/s]
#
#
#
#  24%|██▎       | 2366/10000 [06:09<22:41,  5.61it/s]
#
#
#
#  24%|██▎       | 2367/10000 [06:09<22:09,  5.74it/s]
#
#
#
#  24%|██▎       | 2368/10000 [06:09<21:42,  5.86it/s]
#
#
#
#  24%|██▎       | 2369/10000 [06:10<21:35,  5.89it/s]
#
#
#
#  24%|██▎       | 2370/10000 [06:10<21:21,  5.96it/s]
#
#
#
#  24%|██▎       | 2371/10000 [06:10<21:13,  5.99it/s]
#
#
#
#  24%|██▎       | 2372/10000 [06:10<21:10,  6.00it/s]
#
#
#
#  24%|██▎       | 2373/10000 [06:10<21:10,  6.00it/s]
#
#
#
#  24%|██▎       | 2374/10000 [06:10<21:22,  5.95it/s]
#
#
#
#  24%|██▍       | 2375/10000 [06:11<23:00,  5.52it/s]
#
#
#
#  24%|██▍       | 2376/10000 [06:11<25:44,  4.94it/s]
#
#
#
#  24%|██▍       | 2377/10000 [06:11<31:25,  4.04it/s]
#
#
#
#  24%|██▍       | 2378/10000 [06:11<29:22,  4.33it/s]
#
#
#
#  24%|██▍       | 2379/10000 [06:12<27:27,  4.63it/s]
#
#
#
#  24%|██▍       | 2380/10000 [06:12<25:42,  4.94it/s]
#
#
#
#  24%|██▍       | 2381/10000 [06:12<24:30,  5.18it/s]
#
#
#
#  24%|██▍       | 2382/10000 [06:12<23:55,  5.31it/s]
#
#
#
#  24%|██▍       | 2383/10000 [06:12<23:11,  5.47it/s]
#
#
#
#  24%|██▍       | 2384/10000 [06:13<22:40,  5.60it/s]
#
#
#
#  24%|██▍       | 2385/10000 [06:13<22:34,  5.62it/s]
#
#
#
#  24%|██▍       | 2386/10000 [06:13<22:11,  5.72it/s]
#
#
#
#  24%|██▍       | 2387/10000 [06:13<22:13,  5.71it/s]
#
#
#
#  24%|██▍       | 2388/10000 [06:13<21:55,  5.79it/s]
#
#
#
#  24%|██▍       | 2389/10000 [06:13<21:52,  5.80it/s]
#
#
#
#  24%|██▍       | 2390/10000 [06:14<21:55,  5.78it/s]
#
#
#
#  24%|██▍       | 2391/10000 [06:14<21:46,  5.83it/s]
#
#
#
#  24%|██▍       | 2392/10000 [06:14<21:51,  5.80it/s]
#
#
#
#  24%|██▍       | 2393/10000 [06:14<21:45,  5.83it/s]
#
#
#
#  24%|██▍       | 2394/10000 [06:14<21:43,  5.84it/s]
#
#
#
#  24%|██▍       | 2395/10000 [06:14<21:47,  5.82it/s]
#
#
#
#  24%|██▍       | 2396/10000 [06:15<21:39,  5.85it/s]
#
#
#
#  24%|██▍       | 2397/10000 [06:15<21:44,  5.83it/s]
#
#
#
#  24%|██▍       | 2398/10000 [06:15<21:45,  5.82it/s]
#
#
#
#  24%|██▍       | 2399/10000 [06:15<21:45,  5.82it/s]
#
#
#
#  24%|██▍       | 2400/10000 [06:15<21:42,  5.84it/s]
#
#
#
#  24%|██▍       | 2401/10000 [06:15<21:43,  5.83it/s]
#
#
#
#  24%|██▍       | 2402/10000 [06:16<21:39,  5.85it/s]
#
#
#
#  24%|██▍       | 2403/10000 [06:16<21:41,  5.84it/s]
#
#
#
#  24%|██▍       | 2404/10000 [06:16<21:48,  5.80it/s]
#
#
#
#  24%|██▍       | 2405/10000 [06:16<21:57,  5.76it/s]
#
#
#
#  24%|██▍       | 2406/10000 [06:16<21:49,  5.80it/s]
#
#
#
#  24%|██▍       | 2407/10000 [06:16<22:04,  5.73it/s]
#
#
#
#  24%|██▍       | 2408/10000 [06:17<22:06,  5.72it/s]
#
#
#
#  24%|██▍       | 2409/10000 [06:17<22:08,  5.72it/s]
#
#
#
#  24%|██▍       | 2410/10000 [06:17<21:58,  5.76it/s]
#
#
#
#  24%|██▍       | 2411/10000 [06:17<22:08,  5.71it/s]
#
#
#
#  24%|██▍       | 2412/10000 [06:17<22:11,  5.70it/s]
#
#
#
#  24%|██▍       | 2413/10000 [06:18<22:20,  5.66it/s]
#
#
#
#  24%|██▍       | 2414/10000 [06:18<22:24,  5.64it/s]
#
#
#
#  24%|██▍       | 2415/10000 [06:18<22:20,  5.66it/s]
#
#
#
#  24%|██▍       | 2416/10000 [06:18<22:26,  5.63it/s]
#
#
#
#  24%|██▍       | 2417/10000 [06:18<22:23,  5.64it/s]
#  24%|██▍       | 2418/10000 [06:18<22:10,  5.70it/s]
#
#
#
#  24%|██▍       | 2419/10000 [06:19<22:11,  5.69it/s]
#
#
#
#  24%|██▍       | 2420/10000 [06:19<22:12,  5.69it/s]
#
#
#
#  24%|██▍       | 2421/10000 [06:19<23:10,  5.45it/s]
#
#
#
#  24%|██▍       | 2422/10000 [06:19<22:58,  5.50it/s]
#
#
#
#  24%|██▍       | 2423/10000 [06:19<19:48,  6.38it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b4496f08d65f> in <module>
#       7 model = LeNet(learning_rate=lr)
#       8
# ----> 9 optim_path, loss_steps, accu_steps = loss_landscape_anim(
#      10     n_epochs=10,
#      11     model=model,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/loss_landscape_anim/main.py in loss_landscape_anim(n_epochs, datamodule, model, optimizer, reduction_method, custom_directions, model_dirpath, model_filename, gpus, load_model, output_to_file, output_filename, giffps, sampling, n_frames, seed, return_data)
#     113     pcvariances = reduced_dict.get("pcvariances")
#     114
# --> 115     loss_grid = LossGrid(
#     116         optim_path=optim_path,
#     117         model=model,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/loss_landscape_anim/loss_landscape.py in __init__(self, optim_path, model, data, path_2d, directions, res, tqdm_disable, save_grid, load_grid, filepath)
#     127             print("\nLoss grid loaded from disk.")
#     128         else:
# --> 129             self.loss_values_2d, self.argmin, self.loss_min = self.compute_loss_2d(
#     130                 model, data, tqdm_disable=tqdm_disable
#     131             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/loss_landscape_anim/loss_landscape.py in compute_loss_2d(self, model, data, tqdm_disable)
#     175                     # Load flattened weight vector into model
#     176                     model.init_from_flat_params(w_ij)
# --> 177                     y_pred = model(X)
#     178                     loss_val = model.loss_fn(y_pred, y).item()
#     179                     if loss_val < loss_min:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/loss_landscape_anim/model.py in forward(self, x)
#     191
#     192     def forward(self, x):
# --> 193         x = self.relu(self.conv1(x))
#     194         x = self.pool(x)
#     195         x = self.relu(self.conv2(x))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/activation.py in forward(self, input)
#     100
#     101     def forward(self, input: Tensor) -> Tensor:
# --> 102         return F.relu(input, inplace=self.inplace)
#     103
#     104     def extra_repr(self) -> str:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py in relu(input, inplace)
#    1134         result = torch.relu_(input)
#    1135     else:
# -> 1136         result = torch.relu(input)
#    1137     return result
#    1138
#
# KeyboardInterrupt:
